# %% [markdown]
# # Logistic Regression On Amazon Fine Food Reviews

# %% [markdown]
# ## [ CONTENTS ]
#
# 1. About the dataset<br>
# 2. Objective<br>
# 3. Loading the data<br>
# 4. Data Preprocessing <br>
# 5. Function Definitions<br>
# 6. Bag of Words (BoW)<br>
#     6.1 Bi-Grams & N-Grams<br>
# 7. TF-IDF<br>
# 8. Word2Vec<br>
# 9. Avg W2V & TFIDF-W2V<br>
#     9.1 TF-IDF weighted W2V
# 10. Summary<br>

# %% [markdown]
# ## 1. About the dataset
# 1. Title: Amazon Fine Food Reviews. Link:https://www.kaggle.com/snap/amazon-fine-food-reviews
# 2. Relevant Information: This dataset consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012. Reviews include product and user information, ratings, and a plain text review. It also includes reviews from all other Amazon categories.
# 3. Data includes:
#     * Number of reviews: 568,454<br>
#     * Number of users: 256,059<br>
#     * Number of products: 74,258<br>
#     * Timespan: Oct 1999 - Oct 2012<br>
#     * Number of Attributes/Columns in data: 10
# 4. Attribute Information:
#     * Id
#     * ProductId - unique identifier for the product
#     * UserId - unqiue identifier for the user
#     * ProfileName
#     * HelpfulnessNumerator - number of users who found the review helpful
#     * HelpfulnessDenominator - number of users who indicated whether they found the review helpful or not
#     * Score - rating between 1 and 5
#     * Time - timestamp for the review
#     * Summary - brief summary of the review
#     * Text - text of the review

# %% [markdown]
# ## 2. Objective:
# For a given Amazon review, classify it as "Possitive"(Rating of 4 or 5) or "Negative"(Rating of 1 or 2).<br>
# <br>
# Here I'm using Logistic Regression algorithm to classify reviews as 'positive' or 'negative'. To convert a review text to numerical features I'm using bag of words, TF-IDF, avg Word2Vec, TF-IDF weighted Word2Vec.

# %%
# loading required libraries 
import numpy as np
import pandas as pd 
import matplotlib 
import sqlite3
import string
import gensim
import scipy 
import nltk
import time
import seaborn as sns 
from scipy import stats
from matplotlib import pyplot as plt 

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.grid_search import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support as prf1

from sklearn.model_selection import KFold
from sklearn import cross_validation
from sklearn.model_selection import train_test_split

import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD

#Standardizing the data
def standardizer(data):
    stnd_scaler = StandardScaler(with_mean=False)
    stnd_matx = stnd_scaler.fit_transform(data)
    return stnd_matx

#Applying dimensionality reduction 
def truncated_svd(data):
    svd = TruncatedSVD(n_components = 100, random_state = 0)
    svd_val = svd.fit_transform(data)
    return svd_val

# %% [markdown]
# ## 3. Loading the data

# %%
#Loading the data
connect = sqlite3.connect('final_data.sqlite')

#Ignoring the rows which have rating 3
data = pd.read_sql_query("""
SELECT *
FROM Reviews
""", connect)

# %% [markdown]
# Loading the pre-processed data using sqlite. This dataset has no entry with score 3 which is previously removed. And the scores which are greater than 3 are denoted as 'positive' and which are less than 3 are denoted as 'negative' scores.

# %%
print(data.shape)
data.head()
# Out:
# (364171, 12)
#     index      Id   ProductId          UserId                  ProfileName  \
# 0  138706  150524  0006641040   ACITT7DI6IDDL              shari zychinski
# 1  138688  150506  0006641040  A2IW4PEEKO2R0U                        Tracy
# 2  138689  150507  0006641040  A1S4A3IQ2MU7V4        sally sue "sally sue"
# 3  138690  150508  0006641040     AZGXZ2UUK6X  Catherine Hallberg "(Kate)"
# 4  138691  150509  0006641040  A3CMRKGE0P909G                       Teresa
#
#    HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                     0                       0  positive   939340800
# 1                     1                       1  positive  1194739200
# 2                     1                       1  positive  1191456000
# 3                     1                       1  positive  1076025600
# 4                     3                       4  positive  1018396800
#
#                                       Summary  \
# 0                   EVERY book is educational
# 1  Love the book, miss the hard cover version
# 2               chicken soup with rice months
# 3      a good swingy rhythm for reading aloud
# 4             A great way to learn the months
#
#                                                 Text  \
# 0  this witty little book makes my son laugh at l...
# 1  I grew up reading these Sendak books, and watc...
# 2  This is a fun way for children to learn their ...
# 3  This is a great little book to read aloud- it ...
# 4  This is a book of poetry about the months of t...
#
#                                          CleanedText
# 0  b'witti littl book make son laugh loud recit c...
# 1  b'grew read sendak book watch realli rosi movi...
# 2  b'fun way children learn month year learn poem...
# 3  b'great littl book read nice rhythm well good ...
# 4  b'book poetri month year goe month cute littl ...

# %% [markdown]
# ## 4. Data Preprocessing

# %%
data.Score.value_counts()
# Out:
# positive    307061
# negative     57110
# Name: Score, dtype: int64

# %%
# sorting the data according to the time-stamp
sorted_data = data.sort_values('Time', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
sorted_data.head()
# Out:
#       index      Id   ProductId          UserId               ProfileName  \
# 0    138706  150524  0006641040   ACITT7DI6IDDL           shari zychinski
# 30   138683  150501  0006641040   AJ46FKXOVC7NR        Nicholas A Mesiano
# 424  417839  451856  B00004CXX9   AIUWLEQ1ADEG5          Elizabeth Medina
# 330  346055  374359  B00004CI84  A344SMIA5JECGM           Vincent P. Ross
# 423  417838  451855  B00004CXX9   AJH6LUC1UT1ON  The Phantom of the Opera
#
#      HelpfulnessNumerator  HelpfulnessDenominator     Score       Time  \
# 0                       0                       0  positive  939340800
# 30                      2                       2  positive  940809600
# 424                     0                       0  positive  944092800
# 330                     1                       2  positive  944438400
# 423                     0                       0  positive  946857600
#
#                                                Summary  \
# 0                            EVERY book is educational
# 30   This whole series is great way to spend time w...
# 424                               Entertainingl Funny!
# 330                            A modern day fairy tale
# 423                                         FANTASTIC!
#
#                                                   Text  \
# 0    this witty little book makes my son laugh at l...
# 30   I can remember seeing the show when it aired o...
# 424  Beetlejuice is a well written movie ..... ever...
# 330  A twist of rumplestiskin captured on film, sta...
# 423  Beetlejuice is an excellent and funny movie. K...
#
#                                            CleanedText
# 0    b'witti littl book make son laugh loud recit c...
# 30   b'rememb see show air televis year ago child s...
# 424  b'beetlejuic well written movi everyth excel a...
# 330  b'twist rumplestiskin captur film star michael...
# 423  b'beetlejuic excel funni movi keaton hilari wa...

# %%
def partition(x):
    if x == 'positive':
        return 1
    return 0

#Preparing the filtered data
actualScore = sorted_data['Score']
positiveNegative = actualScore.map(partition) 
sorted_data['Score'] = positiveNegative

# %%
sorted_data.head()
# Out:
#       index      Id   ProductId          UserId               ProfileName  \
# 0    138706  150524  0006641040   ACITT7DI6IDDL           shari zychinski
# 30   138683  150501  0006641040   AJ46FKXOVC7NR        Nicholas A Mesiano
# 424  417839  451856  B00004CXX9   AIUWLEQ1ADEG5          Elizabeth Medina
# 330  346055  374359  B00004CI84  A344SMIA5JECGM           Vincent P. Ross
# 423  417838  451855  B00004CXX9   AJH6LUC1UT1ON  The Phantom of the Opera
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score       Time  \
# 0                       0                       0      1  939340800
# 30                      2                       2      1  940809600
# 424                     0                       0      1  944092800
# 330                     1                       2      1  944438400
# 423                     0                       0      1  946857600
#
#                                                Summary  \
# 0                            EVERY book is educational
# 30   This whole series is great way to spend time w...
# 424                               Entertainingl Funny!
# 330                            A modern day fairy tale
# 423                                         FANTASTIC!
#
#                                                   Text  \
# 0    this witty little book makes my son laugh at l...
# 30   I can remember seeing the show when it aired o...
# 424  Beetlejuice is a well written movie ..... ever...
# 330  A twist of rumplestiskin captured on film, sta...
# 423  Beetlejuice is an excellent and funny movie. K...
#
#                                            CleanedText
# 0    b'witti littl book make son laugh loud recit c...
# 30   b'rememb see show air televis year ago child s...
# 424  b'beetlejuic well written movi everyth excel a...
# 330  b'twist rumplestiskin captur film star michael...
# 423  b'beetlejuic excel funni movi keaton hilari wa...

# %%
score = np.array(sorted_data.Score.reshape(sorted_data.shape[0],1))

# %%
score.shape
# Out:
# (364171, 1)

# %% [markdown]
# ## 5. Function Definitions

# %% [markdown]
# ### [A.] Data Spliting

# %%
# spliting the data
def data_split(data, score):
    # train data 70% and test data 30%
    train_x, test_x, train_y, test_y = train_test_split(data, score, test_size=0.3, shuffle=False)    
    return train_x, test_x, train_y, test_y

# %% [markdown]
# ### [B.] Logistic Regression

# %%
# applying logistic regression with both L1 and L2 normalization
def logistic_regression(X, Y, vectorizer):
    cv_err_l1 = []
    train_err_l1 = []
    cv_err_l2 = []
    train_err_l2 = []
    w_nonz = []
    penalty = ['l1', 'l2']
    c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
    # applying 3-Fold cross validation
    Kfold = KFold(3, shuffle=False, random_state=36)
    for train, cv in Kfold.split(X):
        for l in penalty:
            for c in c_val:
                lr_model = LogisticRegression(penalty = l, C = c, class_weight = 'balanced', n_jobs = -1)
                
                vect_model = vectorizer.fit(X.iloc[train]['CleanedText'].values)
                train_vect = vect_model.transform(X.iloc[train]['CleanedText'].values)
                cv_vect = vect_model.transform(X.iloc[cv]['CleanedText'].values)
            
                lr_model.fit(train_vect, Y[train])
                
                if l == 'l1':
                    cv_err_l1.append(1 - (lr_model.score(cv_vect, Y[cv])))
                    train_err_l1.append(1 - (lr_model.score(train_vect, Y[train])))
                    w_nonz.append(np.count_nonzero(lr_model.coef_))
                else :
                    cv_err_l2.append(1 - (lr_model.score(cv_vect, Y[cv])))
                    train_err_l2.append(1 - (lr_model.score(train_vect, Y[train])))
                    
    return cv_err_l1, train_err_l1, cv_err_l2, train_err_l2, w_nonz

# %%
# applying logistic regression with both L1 and L2 normalization(For W2V)
def lr_w2v(X, Y):
    cv_err_l1 = []
    train_err_l1 = []
    cv_err_l2 = []
    train_err_l2 = []
    w_nonz = []
    penalty = ['l1', 'l2']
    c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
    # applying 3-Fold cross validation
    Kfold = KFold(3, shuffle=False)
    for train, cv in Kfold.split(X):
        for l in penalty:
            for c in c_val:
                lr_model = LogisticRegression(penalty = l, C = c, class_weight = 'balanced', n_jobs = 8)
                
                w2v_model = gensim.models.Word2Vec(X[train], min_count=5, size=100, workers=8)
                train_vect = avg_w2v(X[train], w2v_model)
                cv_vect = avg_w2v(X[cv], w2v_model)
            
                lr_model.fit(train_vect, Y[train])
                
                if l == 'l1':
                    cv_err_l1.append(1 - (lr_model.score(cv_vect, Y[cv])))
                    train_err_l1.append(1 - (lr_model.score(train_vect, Y[train])))
                    w_nonz.append(np.count_nonzero(lr_model.coef_))
                else :
                    cv_err_l2.append(1 - (lr_model.score(cv_vect, Y[cv])))
                    train_err_l2.append(1 - (lr_model.score(train_vect, Y[train])))
                    
    return cv_err_l1, train_err_l1, cv_err_l2, train_err_l2, w_nonz

# %%
# applying logistic regression with both L1 and L2 normalization(For TF-IDF_W2V)
def lr_tfidf_w2v(X1, Y, raw_x):
    X = np.array(X1)
    cv_err_l1 = []
    train_err_l1 = []
    cv_err_l2 = []
    train_err_l2 = []
    w_nonz = []
    penalty = ['l1', 'l2']
    c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
    # applying 3-Fold cross validation
    Kfold = KFold(3, shuffle=False)
    for train, cv in Kfold.split(X):
        for l in penalty:
            for c in c_val:
                lr_model = LogisticRegression(penalty = l, C = c, class_weight = 'balanced', n_jobs = -1)
                
                w2v_model = gensim.models.Word2Vec(X[train], min_count=5, size=100, workers=-1)
                tfidf_dict = tf_idf_vect.fit_transform(raw_x[train])
                train_vect = tfidf_w2v(X1[cv.shape[0]:], w2v_model, tfidf_dict)
                cv_vect = tfidf_w2v(X1[:cv.shape[0]], w2v_model, tfidf_dict)
                
                train_vect = np.nan_to_num(train_vect)
                cv_vect = np.nan_to_num(cv_vect)
            
                lr_model.fit(train_vect, Y[train])
                
                if l == 'l1':
                    cv_err_l1.append(1 - (lr_model.score(cv_vect, Y[cv])))
                    train_err_l1.append(1 - (lr_model.score(train_vect, Y[train])))
                    w_nonz.append(np.count_nonzero(lr_model.coef_))
                else :
                    cv_err_l2.append(1 - (lr_model.score(cv_vect, Y[cv])))
                    train_err_l2.append(1 - (lr_model.score(train_vect, Y[train])))
                    
    return cv_err_l1, train_err_l1, cv_err_l2, train_err_l2, w_nonz

# %% [markdown]
# ### [C.] Error Curve

# %%
# comparing error between cv and train data
def error_comparision(cv_err, train_err):
    sns.set()
    c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
    for i in range(3):
        plt.figure(1)
        plt.figure(figsize=(9,12))
        plt.subplot(3,1,i+1)
        plt.plot(c_val, cv_err[i,:],label = 'cv_error', color = 'r')
        plt.plot(c_val, train_err[i,:],label = 'train_error', color = 'b')
        plt.xscale('log')
        plt.xlabel('C-Values')
        plt.ylabel('Error Values')
        plt.legend()
        plt.title('CV & TRAIN-ERR for Fold '+str(i+1))

# %% [markdown]
# ### [D.] Accuracy Metrics

# %%
# train and test accuracy and ROC plot
def final_test_acc(train_data, train_score, test_data, test_score, l, best_c, name):
    lr_model = LogisticRegression(penalty = l, C = best_c, class_weight = 'balanced', n_jobs = 8)
    lr_model.fit(train_data, train_score)
    
    # Train Metric
    
    print('\t\t\t\tACCURACY METRIC FOR TRAIN-SET\n')
    pred_trn = lr_model.predict(train_data)
    acc_trn = accuracy_score(train_score, pred_trn, normalize=True) * float(100)
    print("\nTrain accuracy for C = '{0}' is '{1}'".format(best_c, acc_trn))
    ytrn_pred_proba = lr_model.predict_proba(train_data)[::,1]
    fpr0, tpr0, thresholds0 = roc_curve(train_score, ytrn_pred_proba)
    
    sns.set()
    plt.figure(figsize=(8,5))
    plt.plot([0,1],[0,1],'k--')
    plt.plot(fpr0, tpr0, label='Logistic Regression', color = 'r')
    plt.xlabel('False-Positive Rate')
    plt.ylabel('True-Positive Rate')
    plt.title('Logistic Regression ROC curve for '+name+' with C '+str(best_c))
    plt.show()
    print('Area under the ROC curve is ', roc_auc_score(train_score, ytrn_pred_proba))
    conf_matx_trn = confusion_matrix(train_score, pred_trn)
    print('\nConfusion Matrix :\n', conf_matx_trn)
    norm_conf_matx_trn = conf_matx_trn / conf_matx_trn.astype(np.float).sum(axis=1).reshape(2,1)
    print('\nNormalized Confusion Matrix :\n', norm_conf_matx_trn)
    plt.figure(figsize=(8,5))
    plot = sns.heatmap(conf_matx_trn, annot=True, fmt = 'g', cmap = 'RdPu',\
                       xticklabels=['Negative Review', 'Positive Review'], yticklabels=['Negative Review','Positive Review'])
    plot.set_yticklabels(plot.get_yticklabels(), rotation = 0, fontsize = 10)
    plt.title('Confusion Matrix Heatmap', fontsize=18)
    
    precision_trn, recall_trn, fscore_trn, support_trn = prf1(train_score, pred_trn)
    print('\nPrecision  : {0:.2f}%, {1:.2f}%'.format(precision_trn[0]*100, precision_trn[1]*100))
    print('Recall     : {0:.2f}%, {1:.2f}%'.format(recall_trn[0]*100, recall_trn[1]*100))
    print('F1-score   : {}'.format(fscore_trn))
    plt.show()
    
    
    
    # Test Metric
    
    print('\t\t\t\tACCURACY METRIC FOR TEST-SET\n')
    pred = lr_model.predict(test_data)
    acc = accuracy_score(test_score, pred, normalize = True) * float(100)
    print("\nTest accuracy for C = '{0}' is '{1}'".format(best_c, acc))
    
    y_pred_proba = lr_model.predict_proba(test_data)[::,1]
    fpr, tpr, thresholds = roc_curve(test_score, y_pred_proba)
    sns.set()
    plt.figure(figsize=(8,5))
    plt.plot([0,1],[0,1],'k--')
    plt.plot(fpr, tpr, label='Logistic Regression', color = 'r')
    plt.xlabel('False-Positive Rate')
    plt.ylabel('True-Positive Rate')
    plt.title('Logistic-Regression ROC curve for '+ name)
    plt.show()
    
    print('Area under the ROC curve is ', roc_auc_score(test_score, y_pred_proba))
    conf_matx = confusion_matrix(test_score,pred)
    print('\nConfusion Matrix :\n', conf_matx)
    norm_conf_matx = conf_matx / conf_matx.astype(np.float).sum(axis=1).reshape(2,1)
    print('\nNormalized Confusion Matrix :\n', norm_conf_matx)
    
    plt.figure(figsize=(8,5))
    plot = sns.heatmap(conf_matx, annot=True, fmt = 'g', cmap = 'RdPu',\
                       xticklabels=['Negative Review', 'Positive Review'], yticklabels=['Negative Review','Positive Review'])
    plot.set_yticklabels(plot.get_yticklabels(), rotation = 0, fontsize = 10)
    plt.title('Confusion Matrix Heatmap', fontsize=18)
    
    precision, recall, fscore, support = prf1(test_score, pred)
    print('\nPrecision  : {0:.2f}%, {1:.2f}%'.format(precision[0]*100, precision[1]*100))
    print('Recall     : {0:.2f}%, {1:.2f}%'.format(recall[0]*100, recall[1]*100))
    print('F1-score   : {}'.format(fscore))

# %% [markdown]
# ### [E.] Grid Search

# %%
# applying grid search to find best c 
def grid_search_cv(data_trn, score_trn, data_test, score_test, l):
    
    tuned_parameters = [{'C': [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]}]
    
    model = GridSearchCV(LogisticRegression(penalty=l, class_weight = 'balanced', n_jobs = -1), tuned_parameters, scoring = 'f1', cv=3, n_jobs = -1)
    model.fit(data_trn, score_trn.reshape(data_trn.shape[0],))

    print(model.best_estimator_)
    print(model.score(data_test, score_test))

# %% [markdown]
# ### [F.] Random Search

# %%
# applying random search to find best c 
def random_search_cv(data_trn, score_trn, data_test, score_test, l):
    
    tuned_parameters={'C': scipy.stats.norm(10)}
    model = RandomizedSearchCV(LogisticRegression(penalty=l, class_weight = 'balanced', n_jobs = -1), tuned_parameters, scoring = 'f1', cv=3, n_jobs = -1)
    model.fit(data_trn, score_trn)
                                                                                   
    print(model.best_estimator_)
    print(model.score(data_test, score_test))

# %% [markdown]
# ### [G.] Multicollinearity Test

# %%
# checking the severity of multicollinearity 
def multi_colinearity_test(data, score, c):
    lr = LogisticRegression(penalty = 'l2', C = c, class_weight = 'balanced', random_state = 36, n_jobs = 8)
    lr.fit(data, score)
    coef_before = lr.coef_
    
    # adding small perturbation
    data.data += data.data.min()
    lr = LogisticRegression(penalty = 'l2', C = c, class_weight = 'balanced', random_state = 36, n_jobs = 8)
    lr.fit(data, score)
    coef_after = lr.coef_
    dist = np.linalg.norm(coef_after-coef_before)
    
    # effect of petubation in terms of euclidean distance
    print("Euclidean distance between these two weight vectors is ", dist)
    
    # effect of pertubation in terms of cosine distance 
    cos = np.dot(coef_after, coef_before.T) / (np.linalg.norm(coef_after) * np.linalg.norm(coef_before))
    print("\nCosine similarity between these two weight vectors is ", cos[0,0])
    print("\ni.e the angle between them is ", np.rad2deg(np.arccos(cos))[0,0])

# %% [markdown]
# ### [H.] Top Features Selection

# %%
# finding top features for each class
def top_features(data, score, vectorizer, top_n, c):

    lr = LogisticRegression(penalty = 'l2', C = c, class_weight = 'balanced', random_state = 36, n_jobs = 8)
    lr.fit(data, score)
    
    # sorting the weight indices 
    pos_class_weight_sorted = -lr.coef_.argsort()
    neg_class_weight_sorted = lr.coef_.argsort()
    
    # top negative features
    print('Top '+str(top_n)+' "NEGATIVE" Features are:\n')
    neg = np.take(vectorizer.get_feature_names(), neg_class_weight_sorted[:top_n])
    for i in range(top_n):
        print(neg[0][i])
        
    # top positive features 
    print('\nTop '+str(top_n)+' "POSITIVE" Features are:\n')
    pos = np.take(vectorizer.get_feature_names(), pos_class_weight_sorted[:top_n])
    for i in range(top_n):
        print(pos[0][i])

# %% [markdown]
# ## 6. Bag of Words (BoW)

# %%
train_x, test_x, train_y, test_y = data_split(sorted_data, score)

# %%
#Applying Bag of Word to cleaned text 
#In sklearn BoW is known as CountVectorizer
count_vect = CountVectorizer(min_df = 0)

# %%
# column standardization 
#final_counts = standardizer(final_counts)

# %% [markdown]
# I'm skipping the column standardization because without it the logistic regression performs a little bit better on this dataset.<br>
# (I've already tested accuracy measures on standardized data, the above code here is only for demonstration purpose)

# %% [markdown]
# ### [A.] Both L1 and L2 Normalized Logistic Regression

# %%
# applying both L1 & L2 normalized logisticr regression
cv_l1_bow, train_l1_bow, cv_l2_bow, train_l2_bow, w_nonz = logistic_regression(train_x, train_y, count_vect)

# %%
# reshaping the cv and test error over 3-Fold cv 
cv_l1_bow = np.reshape(cv_l1_bow,(3, 17))
train_l1_bow = np.reshape(train_l1_bow,(3, 17))
cv_l2_bow = np.reshape(cv_l2_bow,(3, 17))
train_l2_bow = np.reshape(train_l2_bow,(3, 17))

# %%
# effect of λ on sparsity of weight vector in L1 normalization 
c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
print("Number of non-zero weights for different values of C(1/λ) are:\n")
for i in range(len(c_val)):
    print("C = {:10.4f}      λ = {:10.4f}      nonzero_w = {:9.0f}".format(c_val[i],1/c_val[i],np.reshape(w_nonz,(3,17))[0,:][i]))
# Out:
# Number of non-zero weights for different values of C(1/λ) are:
#
# C =     0.0001      λ = 10000.0000      nonzero_w =         2
# C =     0.0005      λ =  2000.0000      nonzero_w =        23
# C =     0.0010      λ =  1000.0000      nonzero_w =        61
# C =     0.0050      λ =   200.0000      nonzero_w =       264
# C =     0.0100      λ =   100.0000      nonzero_w =       440
# C =     0.0500      λ =    20.0000      nonzero_w =      1274
# C =     0.1000      λ =    10.0000      nonzero_w =      2035
# C =     0.5000      λ =     2.0000      nonzero_w =      5744
# C =     1.0000      λ =     1.0000      nonzero_w =      8369
# C =     5.0000      λ =     0.2000      nonzero_w =     15829
# C =    10.0000      λ =     0.1000      nonzero_w =     18389
# C =    50.0000      λ =     0.0200      nonzero_w =     22883
# C =   100.0000      λ =     0.0100      nonzero_w =     24402
# C =   500.0000      λ =     0.0020      nonzero_w =     27329
# C =  1000.0000      λ =     0.0010      nonzero_w =     28417
# C =  5000.0000      λ =     0.0002      nonzero_w =     30339
# C = 10000.0000      λ =     0.0001      nonzero_w =     31014

# %% [markdown]
# #### Observation:
# * We can see here as the λ value increases the non-zero weights count decreases i.e the weight vector becomes more sparse in case of L1 normalized Logistic Regression.

# %% [markdown]
# ### [B.] Error Plot Over Different Values of Hyperparameter C (1 / λ)

# %%
# cv error and test error for L1 normalization 
error_comparision(cv_l1_bow, train_l1_bow)

# %% [markdown]
# #### Observation:
# * From these error plots for L1-Logistic Regression we get optimal error for C-value ranging from 0.1 to 1.
# * Other than that we can observe here, for low C(i.e high λ) we are getting high error because of underfitting and for high C(i.e low λ) we are also getting error value rising becasue it overfits the model.

# %%
# cv error and test error for L2 normalization 
error_comparision(cv_l2_bow, train_l2_bow)

# %% [markdown]
# #### Observation:
# * From these error plots for L2-Logistic Regression we get optimal error for C-value near around 0.1.
# * Other than that we can observe here, for low C(i.e high λ) we are getting high error because of underfitting and for high C(i.e low λ) we are also getting error value rising becasue it overfits the model.

# %%
# calculating bag of words for train and test set
bow_model = count_vect.fit(train_x['CleanedText'].values)
final_counts_train = bow_model.transform(train_x['CleanedText'].values)
final_counts_test = bow_model.transform(test_x['CleanedText'].values)

# %% [markdown]
# ### [C.] Grid Search

# %%
# finding best fit c using grid search (for L1)
grid_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l1')
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9315155139499046

# %%
# finding best fit c using grid search (for L2)
grid_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l2')
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9319617978690985

# %% [markdown]
# #### Observation:
# * From grid-search we are getting optimal C equal to 0.1 for L1 Logistic Regression and the accuracy is 93.15%.
# * From grid-search we are getting optimal C equal to 1.0 for L2 Logistic Regression and the accuracy is nearly same to the L1 accuracy score.

# %% [markdown]
# ### [D.] Random Search

# %%
# finding best fit c using random search (for L1) 
random_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l1')
# Out:
# LogisticRegression(C=9.038735980006326, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9272898853270038

# %%
# finding best fit c using random search (for L2) 
random_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l2')
# Out:
# LogisticRegression(C=7.776004739444883, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9311323247291817

# %% [markdown]
# #### Observation:
# * From random-search we are getting optimal C equal to 9.03 for L1 Logistic Regression with accuracy equal to 93%.
# * From random-search we are getting optimal C equal to 7.77 for L2 Logistic Regression with accuracy 93%.

# %% [markdown]
# ### [E.] Accuracy Matrics

# %%
# accuracy measures for L1
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 'l1', 1.0, 'BoW')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '1.0' is '92.09121328735795'
# Area under the ROC curve is  0.9749299843523785
#
# Confusion Matrix :
#  [[ 35658   2371]
#  [ 17790 199100]]
#
# Normalized Confusion Matrix :
#  [[0.93765284 0.06234716]
#  [0.08202315 0.91797685]]
#
# Precision  : 66.72%, 98.82%
# Recall     : 93.77%, 91.80%
# F1-score   : [0.7796058  0.95180956]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '1.0' is '89.10225899754695'
# Area under the ROC curve is  0.9390768316479922
#
# Confusion Matrix :
#  [[16341  2740]
#  [ 9166 81005]]
#
# Normalized Confusion Matrix :
#  [[0.85640166 0.14359834]
#  [0.10165131 0.89834869]]
#
# Precision  : 64.06%, 96.73%
# Recall     : 85.64%, 89.83%
# F1-score   : [0.73297748 0.93154166]

# %% [markdown]
# #### Observation:
# * For L1 Logistic regression I choosed C to be 1.0 from grid-search and we got here accuracy equal to 89% for test-set.
# * Area under the ROC curve is algo high(i.e 0.94) and false positive and false negative rates are also pretty low which is a good sign.

# %%
# accuracy measures for L2
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 'l2', 1.0, 'BoW')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '1.0' is '92.3866012341175'
# Area under the ROC curve is  0.9763080239592494
#
# Confusion Matrix :
#  [[ 35584   2445]
#  [ 16963 199927]]
#
# Normalized Confusion Matrix :
#  [[0.93570696 0.06429304]
#  [0.07821015 0.92178985]]
#
# Precision  : 67.72%, 98.79%
# Recall     : 93.57%, 92.18%
# F1-score   : [0.7857269  0.95370914]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '1.0' is '89.16907699630214'
# Area under the ROC curve is  0.9400033146671414
#
# Confusion Matrix :
#  [[16377  2704]
#  [ 9129 81042]]
#
# Normalized Confusion Matrix :
#  [[0.85828835 0.14171165]
#  [0.10124098 0.89875902]]
#
# Precision  : 64.21%, 96.77%
# Recall     : 85.83%, 89.88%
# F1-score   : [0.73460874 0.9319618 ]

# %% [markdown]
# #### Observation:
# * For L2 Logistic regression I choosed C to be 1.0 from grid-search and we got here accuracy equal to 89% for test-set.
# * Area under the ROC curve is algo high(i.e 0.94) and false positive and false negative rates are also pretty low which is a good sign.
# * So both L1 and L2 produced nearly same results.

# %% [markdown]
# ### [F.] Multicollinearity Test

# %%
# multicollinearity severity testing 
multi_colinearity_test(final_counts_train, train_y, 1.0)
# Out:
# Euclidean distance between these two weight vectors is  32.6105360660923
#
# Cosine similarity between these two weight vectors is  0.9443136842075925
#
# i.e the angle between them is  19.210918293397967

# %% [markdown]
# #### Observation:
# * After small perturbation I got new weight vector which is 32.6 unit away from the previous weight vector. The euclidean distance is pretty ok i.e there no drastic change in weight vector due to perturbation.
# * Also the Cosine similarity between them is also high(0.94) i.e very small angle(19.2 degree) between these two vectors.
# * So, there is no major change in the weight vector due to perturbation. Hence, multicollinearity is low.
# * That means we can use weight values to predict the feature(word) importance in our corpus.

# %% [markdown]
# ### [G.] Top Features from Each Class

# %%
# printing top features(i.e words here) for each class
top_features(final_counts_train, train_y, count_vect, 10, 1.0)
# Out:
# Top 10 "NEGATIVE" Features are:
#
# mope
# sonewher
# patchwork
# allrecip
# yadayadayada
# mozzerela
# vagan
# hadni
# gind
# grainiest
#
# Top 10 "POSITIVE" Features are:
#
# immediatl
# configuraion
# geriatrx
# wol
# afterschool
# ibezan
# bagh
# oder
# parallel
# oust

# %% [markdown]
# ### 6.1 Bag of Words (Bi-Gram)

# %%
#Adding both uni-gram and bi-gram to BoW
count_vect = CountVectorizer(ngram_range=(1,2), min_df = 0)

# %%
# column standardization 
#final_bigram_counts = standardizer(final_bigram_counts)

# %% [markdown]
# I'm skipping the column standardization because without it the logistic regression performs a little bit better on this dataset.<br>
# (I've already tested accuracy measures on standardized data, the above code here is only for demonstration purpose)

# %% [markdown]
# ### [A.] Both L1 and L2 Normalized Logistic Regression

# %%
# applying both L1 and L2 regularized logistic regression 
cv_l1_bigram, train_l1_bigram, cv_l2_bigram, train_l2_bigram, w_nonz  = logistic_regression(train_x, train_y, count_vect)

# %%
# reshaping the cv error and test error over 3-Fold cv
cv_l1_bi = np.reshape(cv_l1_bigram,(3, 17))
train_l1_bi = np.reshape(train_l1_bigram,(3, 17))
cv_l2_bi = np.reshape(cv_l2_bigram,(3, 17))
train_l2_bi = np.reshape(train_l2_bigram,(3, 17))

# %%
# effect of λ on sparsity of weight vector in L1 normalization 
c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
print("Number of non-zero weights for different values of C(1/λ) are:\n")
for i in range(len(c_val)):
    print("C = {:10.4f}      λ = {:10.4f}      nonzero_w = {:9.0f}".format(c_val[i],1/c_val[i],np.reshape(w_nonz,(3,17))[0,:][i]))
# Out:
# Number of non-zero weights for different values of C(1/λ) are:
#
# C =     0.0001      λ = 10000.0000      nonzero_w =         2
# C =     0.0005      λ =  2000.0000      nonzero_w =        23
# C =     0.0010      λ =  1000.0000      nonzero_w =        63
# C =     0.0050      λ =   200.0000      nonzero_w =       273
# C =     0.0100      λ =   100.0000      nonzero_w =       463
# C =     0.0500      λ =    20.0000      nonzero_w =      1528
# C =     0.1000      λ =    10.0000      nonzero_w =      2813
# C =     0.5000      λ =     2.0000      nonzero_w =     11866
# C =     1.0000      λ =     1.0000      nonzero_w =     17494
# C =     5.0000      λ =     0.2000      nonzero_w =     24808
# C =    10.0000      λ =     0.1000      nonzero_w =     26657
# C =    50.0000      λ =     0.0200      nonzero_w =     30639
# C =   100.0000      λ =     0.0100      nonzero_w =     33465
# C =   500.0000      λ =     0.0020      nonzero_w =     50089
# C =  1000.0000      λ =     0.0010      nonzero_w =     63818
# C =  5000.0000      λ =     0.0002      nonzero_w =    159433
# C = 10000.0000      λ =     0.0001      nonzero_w =    197830

# %% [markdown]
# #### Observation:
# * We can see here as the λ value increases the non-zero weights count decreases i.e the weight vector becomes more sparse in case of L1 normalized Logistic Regression.

# %% [markdown]
# ### [B.] Error Plot Over Different Values of Hyperparameter C (1 / λ)

# %%
# cv error and test error for L1 regularization 
error_comparision(cv_l1_bi, train_l1_bi)

# %% [markdown]
# #### Observation:
# * From these error plots for L1-Logistic Regression we get optimal error for C-value near to 1.
# * Other than that we can observe here, for low C(i.e high λ) we are getting high error because of underfitting and for high C(i.e low λ) we are also getting error value little rising becasue it overfits the model.

# %%
# cv error and test error for L2 regularization 
error_comparision(cv_l2_bi, train_l2_bi)

# %% [markdown]
# #### Observation:
# * From these error plots for L2-Logistic Regression we get optimal error for C-value ranging from 0.1 to 1.
# * Other than that we can observe here, for low C(i.e high λ) we are getting high error because of underfitting and for high C(i.e low λ) we are also getting error value little rising becasue it overfits the model.

# %%
# applying bow(bi-gram) on train and test set 
bi_model = count_vect.fit(train_x['CleanedText'].values)
final_counts_train = bi_model.transform(train_x['CleanedText'].values)
final_counts_test = bi_model.transform(test_x['CleanedText'].values)

# %% [markdown]
# ### [C.] Grid Search

# %%
# finding best fit c using grid search (for L1)
grid_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l1')
# Out:
# LogisticRegression(C=1000.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9574500954503823

# %%
# finding best fit c using grid search (for L2)
grid_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l2')
# Out:
# LogisticRegression(C=10.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9612165363920196

# %% [markdown]
# #### Observation:
# * From grid-search we are getting optimal C equal to 1000 for L1 Logistic Regression and the accuracy is 95.74%.
# * From grid-search we are getting optimal C equal to 10 for L2 Logistic Regression and the accuracy is nearly same(96.1%) to the L1 accuracy score.

# %% [markdown]
# ### [D.] Random Search

# %%
# finding best fit c using random search (for L1)
random_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l1')
# Out:
# LogisticRegression(C=9.697769592215455, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9574003216325626

# %%
# finding best fit c using random search (for L2)
random_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l2')
# Out:
# LogisticRegression(C=10.334907830148143, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.961190791185311

# %% [markdown]
# #### Observation:
# * From random-search we are getting optimal C equal to 9.7 for L1 Logistic Regression with accuracy equal to 95.7%.
# * From random-search we are getting optimal C equal to 10.33 for L2 Logistic Regression with accuracy 96.1%.

# %% [markdown]
# ### [E.] Accuracy Matrics

# %%
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 'l1', 9.7, 'BoW(Bi-Gram)')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '9.7' is '99.9976463111812'
# Area under the ROC curve is  0.9999999978176818
#
# Confusion Matrix :
#  [[ 38029      0]
#  [     6 216884]]
#
# Normalized Confusion Matrix :
#  [[1.00000000e+00 0.00000000e+00]
#  [2.76637927e-05 9.99972336e-01]]
#
# Precision  : 99.98%, 100.00%
# Recall     : 100.00%, 100.00%
# F1-score   : [0.99992112 0.99998617]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '9.7' is '92.95939662431809'
# Area under the ROC curve is  0.955103735142397
#
# Confusion Matrix :
#  [[15239  3842]
#  [ 3850 86321]]
#
# Normalized Confusion Matrix :
#  [[0.79864787 0.20135213]
#  [0.04269665 0.95730335]]
#
# Precision  : 79.83%, 95.74%
# Recall     : 79.86%, 95.73%
# F1-score   : [0.79848048 0.95734581]

# %% [markdown]
# #### Observation:
# * For L1 Logistic regression I choosed C to be 9.7 from grid-search and we got here accuracy equal to 92.95% for test-set.
# * Area under the ROC curve is algo high(i.e 0.95) and false positive and false negative rates are also pretty low which is a good sign.

# %%
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 'l2', 10.335, 'BoW(Bi-Gram)')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '10.335' is '99.9976463111812'
# Area under the ROC curve is  0.9999999974539622
#
# Confusion Matrix :
#  [[ 38029      0]
#  [     6 216884]]
#
# Normalized Confusion Matrix :
#  [[1.00000000e+00 0.00000000e+00]
#  [2.76637927e-05 9.99972336e-01]]
#
# Precision  : 99.98%, 100.00%
# Recall     : 100.00%, 100.00%
# F1-score   : [0.99992112 0.99998617]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '10.335' is '93.58547211950354'
# Area under the ROC curve is  0.962306383693877
#
# Confusion Matrix :
#  [[15423  3658]
#  [ 3350 86821]]
#
# Normalized Confusion Matrix :
#  [[0.80829097 0.19170903]
#  [0.03715163 0.96284837]]
#
# Precision  : 82.16%, 95.96%
# Recall     : 80.83%, 96.28%
# F1-score   : [0.81486765 0.96120675]

# %% [markdown]
# #### Observation:
# * For L2 Logistic regression I choosed C to be 10.335 from grid-search and we got here accuracy equal to 93.6% for test-set.
# * Area under the ROC curve is algo high(i.e 0.96) and false positive and false negative rates are also pretty low which is a good sign.

# %% [markdown]
# ### [F.] Multicollinearity Test

# %%
# multicollinearity severity testing 
multi_colinearity_test(final_counts_train, train_y, count_vect, 10.335)
# Out:
# Euclidean distance between these two weight vectors is  78.98967763476415
#
# Cosine similarity between these two weight vectors is  0.9935140462284642
#
# i.e the angle between them is  6.529193939265072

# %% [markdown]
# #### Observation:
# * After small perturbation I got new weight vector which is 78.9 unit away from the previous weight vector. The euclidean distance is somewhat high.
# * But, the Cosine similarity between them is also high(0.99) i.e small angle(6.5 degree) between these two vectors.
# * So, there is no major change in the weight vector due to perturbation. Hence, multicollinearity is low.
# * That means we can use weight values to predict the feature(word) importance in our corpus.

# %% [markdown]
# ### [G.] Top Features from Each Class

# %%
# printing top features(i.e words here) for each class
top_features(final_counts_train, train_y, count_vect, 10, 10.335)
# Out:
# Top 10 "NEGATIVE" Features are:
#
# two star
# not worth
# worst
# not impress
# not sam
# not happi
# not recommend
# dont recommend
# least favorit
# undrink
#
# Top 10 "POSITIVE" Features are:
#
# beer fantasi
# heartburn tend
# age week
# heavi run
# heat prepar
# heavier commerci
# heat sure
# rubberi usual
# love concept
# beaba allow

# %% [markdown]
# ## 7. TF-IDF

# %%
#Finding TF-IDF vector representation 
tf_idf_vect = TfidfVectorizer(ngram_range=(1,2), min_df = 0)

# %%
#final_tf_idf = standardizer(final_tf_idf)

# %% [markdown]
# I'm skipping the column standardization because without it the logistic regression performs a little bit better on this dataset.<br>
# (I've already tested accuracy measures on standardized data, the above code here is only for demonstration purpose)

# %% [markdown]
# ### [A.] Both L1 and L2 Normalized Logistic Regression

# %%
# applying both L1 & L2 Logistic Regression
cv_l1_tfidf, train_l1_tfidf, cv_l2_tfidf, train_l2_tfidf, w_nonz = logistic_regression(train_x, train_y, tf_idf_vect)

# %%
cv_l1_tf = np.reshape(cv_l1_tfidf,(3, 17))
train_l1_tf = np.reshape(train_l1_tfidf,(3, 17))
cv_l2_tf = np.reshape(cv_l2_tfidf,(3, 17))
train_l2_tf = np.reshape(train_l2_tfidf,(3, 17))

# %%
# checking sparsity over different C
c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
print("Number of non-zero weights for different values of C(1/λ) are:\n")
for i in range(len(c_val)):
    print("C = {:10.4f}      λ = {:10.4f}      nonzero_w = {:9.0f}".format(c_val[i],1/c_val[i],np.reshape(w_nonz,(3,17))[0,:][i]))
# Out:
# Number of non-zero weights for different values of C(1/λ) are:
#
# C =     0.0001      λ = 10000.0000      nonzero_w =         0
# C =     0.0005      λ =  2000.0000      nonzero_w =         0
# C =     0.0010      λ =  1000.0000      nonzero_w =         0
# C =     0.0050      λ =   200.0000      nonzero_w =         7
# C =     0.0100      λ =   100.0000      nonzero_w =        29
# C =     0.0500      λ =    20.0000      nonzero_w =       200
# C =     0.1000      λ =    10.0000      nonzero_w =       379
# C =     0.5000      λ =     2.0000      nonzero_w =      1477
# C =     1.0000      λ =     1.0000      nonzero_w =      3129
# C =     5.0000      λ =     0.2000      nonzero_w =     15978
# C =    10.0000      λ =     0.1000      nonzero_w =     22219
# C =    50.0000      λ =     0.0200      nonzero_w =     28571
# C =   100.0000      λ =     0.0100      nonzero_w =     29906
# C =   500.0000      λ =     0.0020      nonzero_w =     34405
# C =  1000.0000      λ =     0.0010      nonzero_w =     38550
# C =  5000.0000      λ =     0.0002      nonzero_w =     64389
# C = 10000.0000      λ =     0.0001      nonzero_w =     81915

# %% [markdown]
# #### Observation:
# * We can see here as the λ value increases the non-zero weights count decreases i.e the weight vector becomes more sparse in case of L1 normalized Logistic Regression.

# %% [markdown]
# ### [B.] Error Plot Over Different Values of Hyperparameter C (1 / λ)

# %%
# cv error and test error for L1 regularization 
error_comparision(cv_l1_tf, train_l1_tf)

# %% [markdown]
# #### Observation:
# * From these error plots for L1-Logistic Regression we get optimal error for C-value near to 10.
# * Other than that we can observe here, for low C(i.e high λ) we are getting high error because of underfitting and for high C(i.e low λ) we are also getting error value little rising becasue it overfits the model.

# %%
# cv error and test error for L2 regularization 
error_comparision(cv_l2_tf, train_l2_tf)

# %% [markdown]
# #### Observation:
# * From these error plots for L2-Logistic Regression we get optimal error for C-value ranging between 10 to 10000.

# %%
# applying tfidf to train and test set 
tfidf_model = tf_idf_vect.fit(train_x['CleanedText'].values)
final_counts_train = tfidf_model.transform(train_x['CleanedText'].values)
final_counts_test = tfidf_model.transform(test_x['CleanedText'].values)

# %% [markdown]
# ### [C.] Grid Search

# %%
# finding best fit λ using grid search(L1)
grid_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l1')
# Out:
# LogisticRegression(C=10000.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9598895477397991

# %%
# finding best fit λ using grid search(L2)
grid_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l2')
# Out:
# LogisticRegression(C=5000.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9630626951982607

# %% [markdown]
# #### Observation:
# * From grid-search we are getting optimal C equal to 10000 for L1 Logistic Regression and the accuracy is 96%.
# * From grid-search we are getting optimal C equal to 5000 for L2 Logistic Regression and the accuracy is nearly same(96.3%) to the L1 accuracy score.

# %% [markdown]
# ### [D.] Random Search

# %%
# finding best fit λ using random search(L1)
random_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l1')
# Out:
# LogisticRegression(C=10.061203494615594, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9577371940625367

# %%
# finding best fit λ using random search(L2)
random_search_cv(final_counts_train, train_y, final_counts_test, test_y, 'l2')
# Out:
# LogisticRegression(C=12.295921056270508, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=8, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.9608998393144083

# %% [markdown]
# #### Observation:
# * From random-search we are getting optimal C equal to 10 for L1 Logistic Regression and the accuracy is 95.7%.
# * From random-search we are getting optimal C equal to 12.3 for L2 Logistic Regression and the accuracy is nearly same(96%) to the L1 accuracy score.

# %% [markdown]
# ### [E.] Accuracy Matrics

# %%
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 'l1', 10, 'TF-IDF')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '10' is '99.20053036454716'
# Area under the ROC curve is  0.9999264940678572
#
# Confusion Matrix :
#  [[ 38029      0]
#  [  2038 214852]]
#
# Normalized Confusion Matrix :
#  [[1.         0.        ]
#  [0.00939647 0.99060353]]
#
# Precision  : 94.91%, 100.00%
# Recall     : 100.00%, 99.06%
# F1-score   : [0.97390391 0.99527959]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '10' is '93.0719803756453'
# Area under the ROC curve is  0.967343419315865
#
# Confusion Matrix :
#  [[15971  3110]
#  [ 4459 85712]]
#
# Normalized Confusion Matrix :
#  [[0.83701064 0.16298936]
#  [0.04945049 0.95054951]]
#
# Precision  : 78.17%, 96.50%
# Recall     : 83.70%, 95.05%
# F1-score   : [0.80843309 0.95771343]

# %% [markdown]
# #### Observation:
# * For L1 Logistic regression I choosed C to be 10 from grid-search and we got here accuracy equal to 93% for test-set.
# * Area under the ROC curve is algo high(i.e 0.96) and false positive and false negative rates are also pretty low which is a good sign.

# %%
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 'l2', 12.3, 'TF-IDF')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '12.3' is '99.54848402825995'
# Area under the ROC curve is  0.9999292671880662
#
# Confusion Matrix :
#  [[ 38028      1]
#  [  1150 215740]]
#
# Normalized Confusion Matrix :
#  [[9.99973704e-01 2.62957217e-05]
#  [5.30222694e-03 9.94697773e-01]]
#
# Precision  : 97.06%, 100.00%
# Recall     : 100.00%, 99.47%
# F1-score   : [0.98509203 0.99733953]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '12.3' is '93.58547211950354'
# Area under the ROC curve is  0.9720279385942558
#
# Confusion Matrix :
#  [[16132  2949]
#  [ 4059 86112]]
#
# Normalized Confusion Matrix :
#  [[0.84544835 0.15455165]
#  [0.04501447 0.95498553]]
#
# Precision  : 79.90%, 96.69%
# Recall     : 84.54%, 95.50%
# F1-score   : [0.82155225 0.96089984]

# %% [markdown]
# #### Observation:
# * For L2 Logistic regression I choosed C to be 12.3 from random-search and we got here accuracy equal to 93.6% for test-set.
# * Area under the ROC curve is algo high(i.e 0.97) and false positive and false negative rates are also pretty low which is a good sign.

# %% [markdown]
# ### [F.] Multicollinearity Test

# %%
# multicollinearity severity testing 
multi_colinearity_test(final_counts_train, train_y, 12.3)
# Out:
# Euclidean distance between these two weight vectors is  8.132986556730057
#
# Cosine similarity between these two weight vectors is  0.9999139439902154
#
# i.e the angle between them is  0.7516771479155147

# %% [markdown]
# #### Observation:
# * After small perturbation I got new weight vector which is 8.13 unit away from the previous weight vector. The euclidean distance is nearly close i.e there no drastic change in weight vector due to perturbation.
# * Also the Cosine similarity between them is also very high(0.99) i.e very small angle(0.75 degree) between these two vectors.
# * So, there is no major change in the weight vector due to perturbation. Hence, multicollinearity is very low.
# * That means we can use weight values to predict the feature(word) importance in our corpus.

# %% [markdown]
# ### [G.] Top Features from Each Class

# %%
# printing top features(i.e words here) for each class
top_features(final_counts_train, train_y, tf_idf_vect, 10, 12.3)
# Out:
# Top 10 "NEGATIVE" Features are:
#
# disappoint
# worst
# not worth
# two star
# aw
# not recommend
# terribl
# not good
# horribl
# not buy
#
# Top 10 "POSITIVE" Features are:
#
# sauc leak
# age week
# heartburn tend
# beer fantasi
# vego
# heat sure
# butter scorch
# heavili artifici
# need arctic
# held shipment

# %% [markdown]
# ## 8. Word2Vec

# %%
#Importing Libraries 
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

# %%
#Cleaning html tags
def cleanhtml(sentence): 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', sentence)
    return cleantext

#Cleaning special symbols from texts
def cleanpunc(sentence): 
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned

# %%
#cleaning each text
import re
i = 0
list_of_sent = []
for sent in sorted_data['Text'].values:
    filtered_sentence = []
    sent = cleanhtml(sent)
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if(cleaned_words.isalpha()):    
                filtered_sentence.append(cleaned_words.lower())
            else:
                continue 
    list_of_sent.append(filtered_sentence)

# %%
print(sorted_data['Text'].values[0])
print(list_of_sent[0])
# Out:
# this witty little book makes my son laugh at loud. i recite it in the car as we're driving along and he always can sing the refrain. he's learned about whales, India, drooping roses:  i love all the new words this book  introduces and the silliness of it all.  this is a classic book i am  willing to bet my son will STILL be able to recite from memory when he is  in college
# ['this', 'witty', 'little', 'book', 'makes', 'my', 'son', 'laugh', 'at', 'loud', 'i', 'recite', 'it', 'in', 'the', 'car', 'as', 'were', 'driving', 'along', 'and', 'he', 'always', 'can', 'sing', 'the', 'refrain', 'hes', 'learned', 'about', 'whales', 'india', 'drooping', 'i', 'love', 'all', 'the', 'new', 'words', 'this', 'book', 'introduces', 'and', 'the', 'silliness', 'of', 'it', 'all', 'this', 'is', 'a', 'classic', 'book', 'i', 'am', 'willing', 'to', 'bet', 'my', 'son', 'will', 'still', 'be', 'able', 'to', 'recite', 'from', 'memory', 'when', 'he', 'is', 'in', 'college']

# %% [markdown]
# ## 9. Avg Word2Vec & TF-IDF Word2Vec

# %%
#Determining average Word2Vec for each review
def avg_w2v(data, model):
    sent_vectors = []
    for sent in data: 
        sent_vec = np.zeros(100) 
        cnt_words =0; 
        for word in sent: # for each word in a review/sentence
            try:
                vec = model.wv[word]
                sent_vec += vec
                cnt_words += 1
            except:
                pass
        sent_vec /= cnt_words
        sent_vectors.append(sent_vec)
    return np.matrix(sent_vectors)

# %%
#stnd_avg_word2vec = standardizer(avg_word2vec)
#stnd_avg_word2vec.shape

# %% [markdown]
# ### [A.] Both L1 and L2 Normalized Logistic Regression

# %%
train_x, test_x, train_y, test_y = data_split(list_of_sent, score)

# %%
np.array(train_x).shape
# Out:
# (254919,)

# %%
# applying both L1 & L2 Logistic Regression
cv_l1_w2v, train_l1_w2v, cv_l2_w2v, train_l2_w2v, w_nonz = lr_w2v(np.array(train_x), np.array(train_y))

# %%
cv_l1_wv = np.reshape(cv_l1_w2v,(3, 17))
train_l1_wv = np.reshape(train_l1_w2v,(3, 17))
cv_l2_wv = np.reshape(cv_l2_w2v,(3, 17))
train_l2_wv = np.reshape(train_l2_w2v,(3, 17))

# %%
# checking sparsity over different C for L1
c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
print("Number of non-zero weights for different values of C(1/λ) are:\n")
for i in range(len(c_val)):
    print("C = {:10.4f}      λ = {:10.4f}      nonzero_w = {:9.0f}".format(c_val[i],1/c_val[i],np.reshape(w_nonz,(3,17))[0,:][i]))
# Out:
# Number of non-zero weights for different values of C(1/λ) are:
#
# C =     0.0001      λ = 10000.0000      nonzero_w =         0
# C =     0.0005      λ =  2000.0000      nonzero_w =        17
# C =     0.0010      λ =  1000.0000      nonzero_w =        30
# C =     0.0050      λ =   200.0000      nonzero_w =        69
# C =     0.0100      λ =   100.0000      nonzero_w =        81
# C =     0.0500      λ =    20.0000      nonzero_w =        97
# C =     0.1000      λ =    10.0000      nonzero_w =        96
# C =     0.5000      λ =     2.0000      nonzero_w =       100
# C =     1.0000      λ =     1.0000      nonzero_w =       100
# C =     5.0000      λ =     0.2000      nonzero_w =       100
# C =    10.0000      λ =     0.1000      nonzero_w =       100
# C =    50.0000      λ =     0.0200      nonzero_w =       100
# C =   100.0000      λ =     0.0100      nonzero_w =       100
# C =   500.0000      λ =     0.0020      nonzero_w =       100
# C =  1000.0000      λ =     0.0010      nonzero_w =       100
# C =  5000.0000      λ =     0.0002      nonzero_w =       100
# C = 10000.0000      λ =     0.0001      nonzero_w =       100

# %% [markdown]
# #### Observation:
# * We can see here as the λ value increases the non-zero weights count decreases i.e the weight vector becomes more sparse in case of L1 normalized Logistic Regression.

# %% [markdown]
# ### [B.] Error Plot Over Different Values of Hyperparameter C (1 / λ)

# %%
# cv error and test error for L1 regularization 
error_comparision(cv_l1_wv, train_l1_wv)

# %% [markdown]
# #### Observation:
# * From these error plots for L1-Logistic Regression we get optimal error for C-value near to 0.1.

# %%
# cv error and test error for L2 regularization 
error_comparision(cv_l2_wv, train_l2_wv)

# %% [markdown]
# #### Observation:
# * From these error plots for L2-Logistic Regression we get optimal error for C-value in between 0.1 and 1.

# %%
# applying w2v to train and test data
w2v_model = gensim.models.Word2Vec(train_x, min_count=5, size=100, workers=8)
train_vect = avg_w2v(train_x, w2v_model)
test_vect = avg_w2v(test_x, w2v_model)

# %%
train_vect = np.nan_to_num(train_vect)
test_vect = np.nan_to_num(test_vect)

# %% [markdown]
# ### [C.] Grid Search

# %%
# finding best fit C using grid search(L1) 
grid_search_cv(train_vect, train_y, test_vect, test_y, 'l1')
# Out:
# LogisticRegression(C=0.5, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=-1, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.8844267025779144

# %% [markdown]
# #### Observation:
# * From grid-search we are getting optimal C equal to 0.5 for L1 Logistic Regression and the accuracy is 84.4%.
# * Ignoring grid_search for L2 Logistic Regression as it takes too much of time to compute.

# %% [markdown]
# ### [D.] Random Search

# %%
# finding best fit λ using random search 
random_search_cv(train_vect, train_y, test_vect, test_y, 'l1')
# Out:
# LogisticRegression(C=10.619473928730022, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=-1, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.8844521396193293

# %% [markdown]
# #### Observation:
# * From random-search we are getting optimal C equal to 10 for L1 Logistic Regression and the accuracy is 84.4%.
# * Ignoring random-search for L2 Logistic Regression as it takes lot of time to compute.

# %% [markdown]
# ### [E.] Accuracy Matrics

# %%
final_test_acc(train_vect, train_y, test_vect, test_y, 'l1', 0.5, 'AVG_W2V')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '0.5' is '83.49907225432392'
# Area under the ROC curve is  0.920289289892468
#
# Confusion Matrix :
#  [[ 32551   5478]
#  [ 36586 180304]]
#
# Normalized Confusion Matrix :
#  [[0.85595204 0.14404796]
#  [0.16868459 0.83131541]]
#
# Precision  : 47.08%, 97.05%
# Recall     : 85.60%, 83.13%
# F1-score   : [0.60748745 0.89553781]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '0.5' is '82.40398345110387'
# Area under the ROC curve is  0.9179855771835284
#
# Confusion Matrix :
#  [[16472  2609]
#  [16615 73556]]
#
# Normalized Confusion Matrix :
#  [[0.86326712 0.13673288]
#  [0.18426102 0.81573898]]
#
# Precision  : 49.78%, 96.57%
# Recall     : 86.33%, 81.57%
# F1-score   : [0.63149824 0.8844267 ]

# %% [markdown]
# #### Observation:
# * For L1 Logistic regression I choosed C to be 0.5 from random-search and we got here accuracy equal to 82.4% for test-set.
# * Area under the ROC curve is 0.91 and false positive and false negative rates are also reasonable which is good.

# %%
final_test_acc(train_vect, train_y, test_vect, test_y, 'l2', 0.7, 'AVG_W2V')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '0.7' is '83.50966385400854'
# Area under the ROC curve is  0.9202724868911512
#
# Confusion Matrix :
#  [[ 32551   5478]
#  [ 36559 180331]]
#
# Normalized Confusion Matrix :
#  [[0.85595204 0.14404796]
#  [0.1685601  0.8314399 ]]
#
# Precision  : 47.10%, 97.05%
# Recall     : 85.60%, 83.14%
# F1-score   : [0.60764054 0.89561186]
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Test accuracy for C = '0.7' is '82.39757624574379'
# Area under the ROC curve is  0.91796723772945
#
# Confusion Matrix :
#  [[16474  2607]
#  [16624 73547]]
#
# Normalized Confusion Matrix :
#  [[0.86337194 0.13662806]
#  [0.18436083 0.81563917]]
#
# Precision  : 49.77%, 96.58%
# Recall     : 86.34%, 81.56%
# F1-score   : [0.63144177 0.88437697]

# %% [markdown]
# #### Observation:
# * For L2 Logistic regression I choosed C to be 0.7 from random-search and we got here accuracy equal to 82.4% for test-set.
# * Area under the ROC curve is 0.91 and false positive and false negative rates are also reasonable which is good.

# %% [markdown]
# ### 9.1 TF-IDF weighted Word2Vec

# %%
# Determining TF-IDF weighted Word2Vec
def tfidf_w2v(data, model, tfidf_dict):
    tfidf_feat = tf_idf_vect.get_feature_names() 
    tfidf_sent_vectors = []
    row = 0
    for sent in data: 
        sent_vec = np.zeros(100)
        weight_sum = 0 
        for word in sent: 
            try:
                vec = model.wv[word]
                tf_idf = tfidf_dict[row, tfidf_feat.index(word)]
                sent_vec += (vec * tf_idf)
                weight_sum += tf_idf
            except:
                pass
        sent_vec /= weight_sum
        tfidf_sent_vectors.append(sent_vec)
        row += 1
    return np.matrix(tfidf_sent_vectors)

# %% [markdown]
# ### [A.] Both L1 and L2 Normalized Logistic Regression

# %%
train_x, test_x, train_y, test_y, raw_x, raw_y = train_test_split(list_of_sent[:100000], score[:100000], sorted_data.CleanedText[:100000].values,
                                                                 test_size=0.3, shuffle=False)

# %%
# applying L1 & L2 Logistic Regression
cv_l1_tfidf_w2v, train_l1_tfidf_w2v, cv_l2_tfidf_w2v, train_l2_tfidf_w2v, w_nonz = lr_tfidf_w2v(train_x, train_y, raw_x)

# %%
cv_l1_tfidf_wv = np.reshape(cv_l1_tfidf_w2v,(3, 17))
train_l1_tfidf_wv = np.reshape(train_l1_tfidf_w2v,(3, 17))
cv_l2_tfidf_wv = np.reshape(cv_l2_tfidf_w2v,(3, 17))
train_l2_tfidf_wv = np.reshape(train_l2_tfidf_w2v,(3, 17))

# %%
# checking sparsity over different C for L1
c_val = [0.0001,0.0005,0.001,0.005,0.01,0.05,0.1,0.5,1.0,5.0,10.0,50.0,100.0,500.0,1000.0,5000.0,10000.0]
print("Number of non-zero weights for different values of C(1/λ) are:\n")
for i in range(len(c_val)):
    print("C = {:10.4f}      λ = {:10.4f}      nonzero_w = {:9.0f}".format(c_val[i],1/c_val[i],np.reshape(w_nonz,(3,17))[0,:][i]))
# Out:
# Number of non-zero weights for different values of C(1/λ) are:
#
# C =     0.0001      λ = 10000.0000      nonzero_w =         0
# C =     0.0005      λ =  2000.0000      nonzero_w =         0
# C =     0.0010      λ =  1000.0000      nonzero_w =         0
# C =     0.0050      λ =   200.0000      nonzero_w =         0
# C =     0.0100      λ =   100.0000      nonzero_w =         0
# C =     0.0500      λ =    20.0000      nonzero_w =         0
# C =     0.1000      λ =    10.0000      nonzero_w =         0
# C =     0.5000      λ =     2.0000      nonzero_w =         0
# C =     1.0000      λ =     1.0000      nonzero_w =         0
# C =     5.0000      λ =     0.2000      nonzero_w =        10
# C =    10.0000      λ =     0.1000      nonzero_w =        32
# C =    50.0000      λ =     0.0200      nonzero_w =        75
# C =   100.0000      λ =     0.0100      nonzero_w =        89
# C =   500.0000      λ =     0.0020      nonzero_w =        98
# C =  1000.0000      λ =     0.0010      nonzero_w =        99
# C =  5000.0000      λ =     0.0002      nonzero_w =       100
# C = 10000.0000      λ =     0.0001      nonzero_w =       100

# %% [markdown]
# #### Observation:
# * We can see here as the λ value increases the non-zero weights count decreases i.e the weight vector becomes more sparse in case of L1 normalized Logistic Regression.

# %% [markdown]
# ### [B.] Error Plot Over Different Values of Hyperparameter C (1 / λ)

# %%
# cv error and test error for L1 regularization 
error_comparision(cv_l1_tfidf_wv, train_l1_tfidf_wv)

# %% [markdown]
# #### Observation:
# * From these error plots for L1-Logistic Regression we get optimal error for C-value between 1 and 10.

# %%
# cv error and test error for L2 regularization 
error_comparision(cv_l2_tfidf_wv, train_l2_tfidf_wv)

# %% [markdown]
# #### Observation:
# * From these error plots for L2-Logistic Regression we get optimal error for C-value in between 0.01 to 10.

# %%
# applying tf-idf weighted w2v to train and test set 
w2v_model = gensim.models.Word2Vec(train_x, min_count=5, size=100, workers=-1)
tfidf_dict = tf_idf_vect.fit_transform(raw_x)
train_vect = tfidf_w2v(list_of_sent[:70000], w2v_model, tfidf_dict)
test_vect = tfidf_w2v(list_of_sent[70000:100000], w2v_model, tfidf_dict)

# %%
train_vect = np.nan_to_num(train_vect)
test_vect = np.nan_to_num(test_vect)

# %% [markdown]
# ### [C.] Grid Search

# %%
# finding best fit C using grid search(L1) 
grid_search_cv(train_vect, train_y, test_vect, test_y, 'l1')
# Out:
# LogisticRegression(C=50.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=-1, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.8034827963321276

# %%
# finding best fit C using grid search(L2)
grid_search_cv(train_vect, train_y, test_vect, test_y, 'l2')
# Out:
# LogisticRegression(C=500.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=-1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.8033573141486811

# %% [markdown]
# #### Observation:
# * From grid-search we are getting optimal C equal to 50 for L1 Logistic Regression and the accuracy is 80%.
# * From grid-search we are getting optimal C equal to 500 for L2 Logistic Regression and the accuracy is nearly equal to the L1 accuracy score.

# %% [markdown]
# ### [D.] Random Search

# %%
# finding best fit C using random search(L1)
random_search_cv(train_vect, train_y, test_vect, test_y, 'l1')
# Out:
# LogisticRegression(C=11.270079705274796, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=-1, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.8035830687385663

# %%
# finding best fit C using random search(L2)
random_search_cv(train_vect, train_y, test_vect, test_y, 'l2')
# Out:
# LogisticRegression(C=10.779316567242123, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=-1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# 0.8002700194076449

# %% [markdown]
# #### Observation:
# * From random-search we are getting optimal C equal to 11.3 for L1 Logistic Regression and the accuracy is 80%.
# * From random-search we are getting optimal C equal to 10.7 for L2 Logistic Regression and the accuracy is nearly equal to the L1 accuracy score.

# %% [markdown]
# ### [E.] Accuracy Matrics

# %%
final_test_acc(train_vect, train_y, test_vect, test_y, 'l1', 50, 'TF-IDF_W2V')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '50' is '65.26142857142857'
# Area under the ROC curve is  0.7124456801542685
#
# Confusion Matrix :
#  [[ 5414  2754]
#  [21563 40269]]
#
# Normalized Confusion Matrix :
#  [[0.66283056 0.33716944]
#  [0.34873528 0.65126472]]
#
# Precision  : 20.07%, 93.60%
# Recall     : 66.28%, 65.13%
# F1-score   : [0.30809503 0.76808927]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for C = '50' is '68.85333333333334'
# Area under the ROC curve is  0.5914737116726623
#
# Confusion Matrix :
#  [[ 1554  2549]
#  [ 6795 19102]]
#
# Normalized Confusion Matrix :
#  [[0.37874726 0.62125274]
#  [0.2623856  0.7376144 ]]
#
# Precision  : 18.61%, 88.23%
# Recall     : 37.87%, 73.76%
# F1-score   : [0.24959846 0.8034828 ]

# %% [markdown]
# #### Observation:
# * For L1 Logistic regression I choosed C to be 50 from random-search and we got here accuracy equal to 68.8% for test-set which is ok but not that good.
# * Area under the ROC curve is 0.6 and false negative rate is high, that means for TF-IDF weighted word2vec representation our model becomes little biased towards positive class which is not good.

# %%
final_test_acc(train_vect, train_y, test_vect, test_y, 'l2', 500, 'TF-IDF_W2V')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for C = '500' is '65.25714285714285'
# Area under the ROC curve is  0.7121677161308092
#
# Confusion Matrix :
#  [[ 5399  2769]
#  [21551 40281]]
#
# Normalized Confusion Matrix :
#  [[0.66099412 0.33900588]
#  [0.34854121 0.65145879]]
#
# Precision  : 20.03%, 93.57%
# Recall     : 66.10%, 65.15%
# F1-score   : [0.30747765 0.76812036]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for C = '500' is '68.84'
# Area under the ROC curve is  0.5917728682585149
#
# Confusion Matrix :
#  [[ 1557  2546]
#  [ 6802 19095]]
#
# Normalized Confusion Matrix :
#  [[0.37947843 0.62052157]
#  [0.26265591 0.73734409]]
#
# Precision  : 18.63%, 88.24%
# Recall     : 37.95%, 73.73%
# F1-score   : [0.24987963 0.80335731]

# %% [markdown]
# #### Observation:
# * For L2 Logistic regression I choosed C to be 500 from grid-search and we got here accuracy equal to 68.8%.
# * Area under the ROC curve is 0.6 and again false negative rate is high, that means for TF-IDF weighted word2vec representation our model becomes little biased towards positive class which is bad.

# %% [markdown]
# ## 10. Summary:

# %% [markdown]
# ### Approach:
# <p align="center">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;From all Amazon fine food reviews data-points i have taken only the reviews that have score 1, 2, 4 or 5. Then I applied some pre-processing methods to make data best fit to apply Logistic Regression. After that I have declared some useful functions to modularize the whole process. For our end goal i.e to classify a review whether it is positive or not by using Logistic Regression, we need to convert the textual data to numerial one. To do so i have used these four(given below) vectorization methods.<br>
# </p>
# <br>
# 1. Bag of Words(BoW)<br>
# 2. TF-IDF<br>
# 3. Avg Word2Vec<br>
# 4. TF-IDF weighted W2V<br>
# <p align="center">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Before applying any model to our data we need to split the data into train and test set. Here I have taken 70% of the total data(364171 data-points) as train-set and rest 30% as test-data. The important part here is "I have sorted the data in ascending order of time stamp of the reviews" and then splitted the whole data without shuffling it. The only problem with this data set is that it is a imbalanced dataset i.e there is a mismatch between number of instances of each class. Here i'm having 307061 positive data-points and 57110 negative data-points. It means the given dataset is nearly 85% positive & 15% negative.
# </p>
# <h3> Results:</h3>
# <p align="center">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In Logistic Regression we have got lambda(λ) which is a hyper-parameter which handles the trade-off between overfitting and underfitting. To find best fit lambda(λ) i have used 3-Fold cross validation for each vectorization method and the performance of the model is compared by various accuracy matrics(ROC-AUC curve, precision, recall, F1-Score etc.) for each vectorization.
# </p>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>1. BoW(Uni-Gram)</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For BoW(Uni-Gram) representation, we got best-fit λ = 1 from 3-Fold cross validation and grid-search and random-search. And the accuracy metric for train and test data, taking λ = 1, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>Lambda(λ)</th>
#     <th>Penalty</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>1.0</td>
#     <td>L1</td>
#     <td>92%</td>
#     <td>66.72%, 98.82%</td>
#     <td>93.77%, 91.80%</td>
#     <td>0.78  0.95</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>1.0</td>
#     <td>L1</td>
#     <td>89%</td>
#     <td>64.06%, 96.73%</td>
#     <td>85.64%, 89.83%</td>
#     <td>0.73 0.93</td>
#   </tr>
#     <tr>
#     <td>Train</td>
#     <td>1.0</td>
#     <td>L2</td>
#     <td>92%</td>
#     <td>67.72%, 98.79%</td>
#     <td>93.57%, 92.18%</td>
#     <td>0.78  0.95</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>1.0</td>
#     <td>L2</td>
#     <td>89%</td>
#     <td>64.21%, 96.77%</td>
#     <td>85.83%, 89.88%</td>
#     <td>0.73 0.93</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 92% accuracy for train-data and 89% for test-data. But from F1-Score it is clear that our model is not that good in predicting negative class compared to the positive prediction. This problem occurs due the imbalanced data, still 0.73 F1-Score for negative prediction is pretty good as total negative data-points are only 15% of total data.
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>2. BoW(Bi-Gram)</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For BoW(Bi-Gram) representation, we got best-fit λ(L1) = 0.1, λ(L2) = 0.09 from 3-Fold cross validation and random-search. And the accuracy metric for train and test data, taking λ = 0.1 & 0.09, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>Lambda(λ)</th>
#     <th>Penalty</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>0.1</td>
#     <td>L1</td>
#     <td>99.9%</td>
#     <td>99.98%, 100.00%</td>
#     <td>100.00%, 100.00%</td>
#     <td>0.99 0.99</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>0.1</td>
#     <td>L1</td>
#     <td>92.9%</td>
#     <td>79.83%, 95.74%</td>
#     <td>79.86%, 95.73%</td>
#     <td>0.80 0.95</td>
#   </tr>
#     <tr>
#     <td>Train</td>
#     <td>0.09</td>
#     <td>L2</td>
#     <td>99.9%</td>
#     <td>99.98%, 100.00%</td>
#     <td>100.00%, 100.00%</td>
#     <td>0.99 0.99</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>0.09</td>
#     <td>L2</td>
#     <td>93.5%</td>
#     <td>82.16%, 95.96%</td>
#     <td>80.83%, 96.28%</td>
#     <td>0.81 0.96</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 99% accuracy for train-data and 93.5% for test-data. But BoW(Bi-Gram) helped the model a little bit in classifing negative reviews than the BoW(Uni-Gram).
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>3. TF-IDF</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For TF-IDF representation, we got best-fit λ(L1) = 0.1, λ(L2) = 0.08 from 3-Fold cross validation and random & grid-search. And the accuracy metric for train and test data, taking λ = 0.1 & 0.08, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>Lambda(λ)</th>
#     <th>Penalty</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>0.1</td>
#     <td>L1</td>
#     <td>99.2%</td>
#     <td>94.91%, 100.00%</td>
#     <td>100.00%, 99.06%</td>
#     <td>0.97 0.99</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>0.1</td>
#     <td>L1</td>
#     <td>93%</td>
#     <td>78.17%, 96.50%</td>
#     <td>83.70%, 95.05%</td>
#     <td>0.80 0.95</td>
#   </tr>
#     <tr>
#     <td>Train</td>
#     <td>0.08</td>
#     <td>L2</td>
#     <td>99.5%</td>
#     <td>97.06%, 100.00%</td>
#     <td>100.00%, 99.47%</td>
#     <td>0.98 0.99</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>0.08</td>
#     <td>L2</td>
#     <td>93.5%</td>
#     <td>79.90%, 96.69%</td>
#     <td>84.54%, 95.50%</td>
#     <td>0.82 0.96</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 99.5% accuracy with high F1-Scores for train-data and 93.5% for test-data. And for test-data, negative class F1-Score is 0.82 which is better than the BoW(Bi-Gram). So the TF-IDF representation helped the model classify negative classes better than BoW. Overall classification is also good.
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>4. AVG Word2Vec</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For AVG Word2Vec representation, we got best-fit λ(L1) = 2.0, λ(L2) = 1.4 from 3-Fold cross validation and random & grid-search. And the accuracy metric for train and test data, taking λ = 2.0 & 1.4, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>Lambda(λ)</th>
#     <th>Penalty</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>2.0</td>
#     <td>L1</td>
#     <td>83.4%</td>
#     <td>47.08%, 97.05%</td>
#     <td>85.60%, 83.13%</td>
#     <td>0.60 0.89</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>2.0</td>
#     <td>L1</td>
#     <td>82.4%</td>
#     <td>49.78%, 96.57%</td>
#     <td>86.33%, 81.57%</td>
#     <td>0.63 0.88</td>
#   </tr>
#     <tr>
#     <td>Train</td>
#     <td>1.4</td>
#     <td>L2</td>
#     <td>83.5%</td>
#     <td>47.10%, 97.05%</td>
#     <td>85.60%, 83.14%</td>
#     <td>0.60 0.89</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>1.4</td>
#     <td>L2</td>
#     <td>82.4%</td>
#     <td>47.10%, 97.05%</td>
#     <td>85.60%, 83.14%</td>
#     <td>0.60 0.89</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 83.5% accuracy with low negative class F1-Scores for train-data and 82.4% for test-data. And for test-data, negative class F1-Score is 0.63 which is even lower than the BoW. So the Avg-Word2Vec representation did not help the model classify negative classes properly. So for our model this representaion is not recommended to use.
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>5. TFIDF weighted W2V</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For TFIDF weighted W2V representation, we got best-fit λ(L1) = 0.02, λ(L2) = 0.002 from 3-Fold cross validation and random & grid-search. And the accuracy metric for train and test data, taking λ = 0.02 & 0.002, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>Lambda(λ)</th>
#     <th>Penalty</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>0.02</td>
#     <td>L1</td>
#     <td>65.2%</td>
#     <td>20.07%, 93.60%</td>
#     <td>66.28%, 65.13%</td>
#     <td>0.30 0.76</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>0.02</td>
#     <td>L1</td>
#     <td>68.8%</td>
#     <td>18.61%, 88.23%</td>
#     <td>37.87%, 73.76%</td>
#     <td>0.25 0.80</td>
#   </tr>
#     <tr>
#     <td>Train</td>
#     <td>0.002</td>
#     <td>L2</td>
#     <td>65.2%</td>
#     <td>20.03%, 93.57%</td>
#     <td>66.10%, 65.15%</td>
#     <td>0.30 0.76</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>0.002</td>
#     <td>L2</td>
#     <td>68.8%</td>
#     <td>18.63%, 88.24%</td>
#     <td>37.95%, 73.73%</td>
#     <td>0.25 0.80</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 65.2% accuracy with worse negative class F1-Scores for train-data and 68.8% for test-data. And for test-data, negative class F1-Score is 0.25 which is the worst till now. So the TFIDF-weighted-W2V representation did not help the model classify properly.
# <h3> Conclusion:</h3><br>
# 1. The model performed better for BoW(both Uni-Gram and Bi-Gram) vectorization than TF-IDF vectorization to classify the reviews.<br>
# 2. The Logistic Regression performed very well, even the dataset is 85%-15% imbalanced, with 93.5% accuracy & 0.82, 0.96 F1 Scores.
