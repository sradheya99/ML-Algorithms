# %% [markdown]
# # k-NN On Amazon Fine Food Reviews

# %% [markdown]
# ## [ CONTENTS ]
#
# 1. About the dataset<br>
# 2. Objective<br>
# 3. Loading the data<br>
# 4. Data Preprocessing <br>
# 5. k-NN on k-Fold cross validation<br>
# 6. Bag of Words (BoW)<br>
#     6.1 Bi-Grams & N-Grams<br>
# 7. TF-IDF<br>
# 8. Word2Vec<br>
# 9. Avg Word2Vec & TF-IDF Word2Vec<br>
# 10. Conclusion<br>

# %% [markdown]
# ## 1. About the dataset
# 1. Title: Amazon Fine Food Reviews. Link:https://www.kaggle.com/snap/amazon-fine-food-reviews
# 2. Relevant Information: This dataset consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012. Reviews include product and user information, ratings, and a plain text review. It also includes reviews from all other Amazon categories.
# 3. Data includes:
#     * Number of reviews: 568,454<br>
#     * Number of users: 256,059<br>
#     * Number of products: 74,258<br>
#     * Timespan: Oct 1999 - Oct 2012<br>
#     * Number of Attributes/Columns in data: 10
# 4. Attribute Information:
#     * Id
#     * ProductId - unique identifier for the product
#     * UserId - unqiue identifier for the user
#     * ProfileName
#     * HelpfulnessNumerator - number of users who found the review helpful
#     * HelpfulnessDenominator - number of users who indicated whether they found the review helpful or not
#     * Score - rating between 1 and 5
#     * Time - timestamp for the review
#     * Summary - brief summary of the review
#     * Text - text of the review

# %% [markdown]
# ## 2. Objective:
# For a given Amazon review, classify it as "Possitive"(Rating of 4 or 5) or "Negative"(Rating of 1 or 2).<br>
# <br>
# Here I'm using k nearest neighbor algorithm to classify reviews as 'positive' or 'negative'. To convert a review text to numerical features I'm using bag of words, TF-IDF, avg Word2Vec, TF-IDF weighted Word2Vec.

# %%
#Importing required libraries
import numpy as np
import pandas as pd 
import matplotlib 
import sqlite3
import string
import nltk
import time
from matplotlib import pyplot as plt 
import seaborn as sns 
from sklearn import neighbors 
from matplotlib.colors import ListedColormap
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.metrics import precision_recall_fscore_support as prf1
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import KFold
from sklearn import cross_validation
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD

#Standardizing the data
def standardizer(data):
    stnd_scaler = StandardScaler(with_mean=False)
    stnd_matx = stnd_scaler.fit_transform(data)
    return stnd_matx

#Applying dimensionality reduction 
def truncated_svd(data):
    svd = TruncatedSVD(n_components = 500, random_state = 0)
    svd_val = svd.fit_transform(data)
    return svd_val

# %% [markdown]
# ## 3. Loading the data

# %%
#Loading the data
connect = sqlite3.connect('final_data.sqlite')

#Ignoring the rows which have rating 3
data = pd.read_sql_query("""
SELECT *
FROM Reviews
""", connect)

# %% [markdown]
# Loading the pre-processed data using sqlite. This dataset has no entry with score 3 which is previously removed. And the scores which are greater than 3 are denoted as 'positive' and which are less than 3 are denoted as 'negative' scores.

# %%
data.shape
# Out:
# (364171, 12)

# %%
data.head()
# Out:
#     index      Id   ProductId          UserId                  ProfileName  \
# 0  138706  150524  0006641040   ACITT7DI6IDDL              shari zychinski
# 1  138688  150506  0006641040  A2IW4PEEKO2R0U                        Tracy
# 2  138689  150507  0006641040  A1S4A3IQ2MU7V4        sally sue "sally sue"
# 3  138690  150508  0006641040     AZGXZ2UUK6X  Catherine Hallberg "(Kate)"
# 4  138691  150509  0006641040  A3CMRKGE0P909G                       Teresa
#
#    HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                     0                       0  positive   939340800
# 1                     1                       1  positive  1194739200
# 2                     1                       1  positive  1191456000
# 3                     1                       1  positive  1076025600
# 4                     3                       4  positive  1018396800
#
#                                       Summary  \
# 0                   EVERY book is educational
# 1  Love the book, miss the hard cover version
# 2               chicken soup with rice months
# 3      a good swingy rhythm for reading aloud
# 4             A great way to learn the months
#
#                                                 Text  \
# 0  this witty little book makes my son laugh at l...
# 1  I grew up reading these Sendak books, and watc...
# 2  This is a fun way for children to learn their ...
# 3  This is a great little book to read aloud- it ...
# 4  This is a book of poetry about the months of t...
#
#                                          CleanedText
# 0  b'witti littl book make son laugh loud recit c...
# 1  b'grew read sendak book watch realli rosi movi...
# 2  b'fun way children learn month year learn poem...
# 3  b'great littl book read nice rhythm well good ...
# 4  b'book poetri month year goe month cute littl ...

# %% [markdown]
# ## 4. Data Preprocessing

# %% [markdown]
# To apply k-NN, the loaded data still needs further preprocessing.

# %%
positive_data = data[data.Score == 'positive']
negative_data = data[data.Score == 'negative']

# %%
balanced_data = pd.concat([positive_data.iloc[:15000, :], negative_data.iloc[:15000, :]])

# %%
#Sorting the data according to the time-stamp
sorted_data = balanced_data.sort_values('Time', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

# %%
sorted_data.head()
# Out:
#       index      Id   ProductId          UserId               ProfileName  \
# 0    138706  150524  0006641040   ACITT7DI6IDDL           shari zychinski
# 30   138683  150501  0006641040   AJ46FKXOVC7NR        Nicholas A Mesiano
# 424  417839  451856  B00004CXX9   AIUWLEQ1ADEG5          Elizabeth Medina
# 330  346055  374359  B00004CI84  A344SMIA5JECGM           Vincent P. Ross
# 423  417838  451855  B00004CXX9   AJH6LUC1UT1ON  The Phantom of the Opera
#
#      HelpfulnessNumerator  HelpfulnessDenominator     Score       Time  \
# 0                       0                       0  positive  939340800
# 30                      2                       2  positive  940809600
# 424                     0                       0  positive  944092800
# 330                     1                       2  positive  944438400
# 423                     0                       0  positive  946857600
#
#                                                Summary  \
# 0                            EVERY book is educational
# 30   This whole series is great way to spend time w...
# 424                               Entertainingl Funny!
# 330                            A modern day fairy tale
# 423                                         FANTASTIC!
#
#                                                   Text  \
# 0    this witty little book makes my son laugh at l...
# 30   I can remember seeing the show when it aired o...
# 424  Beetlejuice is a well written movie ..... ever...
# 330  A twist of rumplestiskin captured on film, sta...
# 423  Beetlejuice is an excellent and funny movie. K...
#
#                                            CleanedText
# 0    b'witti littl book make son laugh loud recit c...
# 30   b'rememb see show air televis year ago child s...
# 424  b'beetlejuic well written movi everyth excel a...
# 330  b'twist rumplestiskin captur film star michael...
# 423  b'beetlejuic excel funni movi keaton hilari wa...

# %%
def partition(x):
    if x == 'positive':
        return 1
    return 0

#Preparing the filtered data
actualScore = sorted_data['Score']
positiveNegative = actualScore.map(partition) 
sorted_data['Score'] = positiveNegative

# %%
score = np.array(sorted_data.Score.reshape(sorted_data.shape[0],1))

# %% [markdown]
# ## 5. k-NN & k-Fold Cross Validation

# %%
# Train-Test splitting 
def data_split(data, score):
    train_x, test_x, train_y, test_y = train_test_split(data, score, test_size = 0.3, shuffle = False)
    return train_x, test_x, train_y, test_y

# %%
#Defining K-NN on K-Folds 
def cross_val(X, Y, vectorizer, name, algo):

    # spliting the train data set into cross validation train and cross validation test
    kfold = KFold(3, shuffle = False, random_state = 1)
    
    k_val = np.arange(1, 50, 3)
    cv_err = []
    train_err = []
    
    for train, cv in kfold.split(X):
        
        if name in ['BoW','TFIDF']:
            
            vect_model = vectorizer.fit(X.iloc[train]['CleanedText'].values)
            train_vect = standardizer(vect_model.transform(X.iloc[train]['CleanedText'].values))
            cv_vect = standardizer(vect_model.transform(X.iloc[cv]['CleanedText'].values))
            
            if algo == 'kd_tree':
                train_vect = train_vect.toarray()
                cv_vect = cv_vect.toarray()
                
            for i in k_val:
                    
                clf = KNeighborsClassifier(n_neighbors = i, algorithm = algo, n_jobs = -1) 
                clf.fit(train_vect, Y[train])
                
                train_err.append(1 - (clf.score(train_vect, Y[train])))
                cv_err.append(1 - (clf.score(cv_vect, Y[cv])))
                
        elif name == 'Word2Vec':
                
            w2v_model = gensim.models.Word2Vec(X[train], min_count=5, size=100, workers=8)
            train_vect = avg_w2v(X[train], w2v_model)
            cv_vect = avg_w2v(X[cv], w2v_model)
            
            for i in k_val:
                
                clf = KNeighborsClassifier(n_neighbors = i, algorithm = algo, n_jobs = -1)
                clf.fit(train_vect, Y[train])
                
                cv_err.append(1 - (clf.score(cv_vect, Y[cv])))
                train_err.append(1 - (clf.score(train_vect, Y[train])))
                
        else:
                
            raw_x = vectorizer # its the text data n't a vectorizer for tfidf-w2v 
            X1 = np.array(X)
            w2v_model = gensim.models.Word2Vec(X1[train], min_count=5, size=100, workers=-1)
            tfidf_model = tf_idf_vect.fit(raw_x[train])
                #tfidf_dict = tf_idf_vect.fit_transform(raw_x[train])
            tfidf_dict = dict(zip(tf_idf_vect.get_feature_names(), list(tf_idf_vect.idf_)))
            train_vect = tfidf_w2v(X[cv.shape[0]:], w2v_model, tfidf_dict)
            cv_vect = tfidf_w2v(X[:cv.shape[0]], w2v_model, tfidf_dict)
                
            train_vect = np.nan_to_num(train_vect)
            cv_vect = np.nan_to_num(cv_vect)
            
            for i in k_val:
            
                clf = KNeighborsClassifier(n_neighbors = i, algorithm = algo, n_jobs = -1)
                clf.fit(standardizer(train_vect), Y[train])
                
                cv_err.append(1 - (clf.score(standardizer(cv_vect), Y[cv])))
                train_err.append(1 - (clf.score(standardizer(train_vect), Y[train])))
    
    return train_err, cv_err

# %%
#Ploting errors for cross validation and test set
def error_comparision(cv_err, train_err):
    sns.set()
    k_val = np.arange(1,50,3)
    for i in range(3):
        plt.figure(1)
        plt.figure(figsize=(9,12))
        plt.subplot(3,1,i+1)
        plt.plot(k_val, cv_err[i, :],label = 'cv_error', color = 'red')
        plt.plot(k_val, train_err[i, :],label = 'train_error', color = 'purple')
        plt.xlabel('K-Values')
        plt.ylabel('Error Values')
        plt.legend()
        plt.title('CV & TRAIN-ERR for Fold '+str(i+1))

# %%
#Test Accuracy and ROC plot
def final_test_acc(train_data, train_score, test_data, test_score, best_k, name, algo):
    knn = KNeighborsClassifier(n_neighbors = best_k, algorithm = algo, n_jobs = -1)
    knn.fit(train_data, train_score)
    
    
    # TRAIN METRIC
    
    print('\t\t\t\tACCURACY METRIC FOR TRAIN-SET\n')
    pred_trn = knn.predict(train_data)
    acc_trn = accuracy_score(train_score, pred_trn, normalize=True) * float(100)
    print("\nTrain accuracy for K = '{0}' is '{1}'".format(best_k, acc_trn))
    ytrn_pred_proba = knn.predict_proba(train_data)[::,1]
    fpr0, tpr0, thresholds0 = roc_curve(train_score, ytrn_pred_proba)
    
    sns.set()
    plt.figure(figsize=(8,5))
    plt.plot([0,1],[0,1],'k--')
    plt.plot(fpr0, tpr0, label='KNN', color = 'r')
    plt.xlabel('False-Positive Rate')
    plt.ylabel('True-Positive Rate')
    plt.title('KNN ROC curve for '+name+' with K '+str(best_k))
    plt.show()
    print('Area under the ROC curve is ', roc_auc_score(train_score, ytrn_pred_proba))
    conf_matx_trn = confusion_matrix(train_score, pred_trn)
    print('\nConfusion Matrix :\n', conf_matx_trn)
    norm_conf_matx_trn = conf_matx_trn / conf_matx_trn.astype(np.float).sum(axis=1).reshape(2,1)
    print('\nNormalized Confusion Matrix :\n', norm_conf_matx_trn)
    plt.figure(figsize=(8,5))
    plot = sns.heatmap(conf_matx_trn, annot=True, fmt = 'g', cmap = 'RdPu',\
                       xticklabels=['Negative Review', 'Positive Review'], yticklabels=['Negative Review','Positive Review'])
    plot.set_yticklabels(plot.get_yticklabels(), rotation = 0, fontsize = 10)
    plt.title('Confusion Matrix Heatmap', fontsize=18)
    
    precision_trn, recall_trn, fscore_trn, support_trn = prf1(train_score, pred_trn)
    print('\nPrecision  : {0:.2f}%, {1:.2f}%'.format(precision_trn[0]*100, precision_trn[1]*100))
    print('Recall     : {0:.2f}%, {1:.2f}%'.format(recall_trn[0]*100, recall_trn[1]*100))
    print('F1-score   : {}'.format(fscore_trn))
    plt.show()
    
    
    # TEST METRIC
    
    print('\n\n\n\n\n')
    print('\t\t\t\tACCURACY METRIC FOR TEST-SET\n')
    pred = knn.predict(test_data)
    acc = accuracy_score(test_score, pred, normalize=True) * float(100)
    
    print("\nTest accuracy for K = '{0}' is '{1}'".format(best_k, acc))
    y_pred_proba = knn.predict_proba(test_data)[::,1]
    fpr, tpr, thresholds = roc_curve(test_score, y_pred_proba)
    
    sns.set()
    plt.figure(figsize=(8,5))
    plt.plot([0,1],[0,1],'k--')
    plt.plot(fpr, tpr, label='KNN', color = 'r')
    plt.xlabel('False-Positive Rate')
    plt.ylabel('True-Positive Rate')
    plt.title('KNN ROC curve for '+name+' with K '+str(best_k))
    plt.show()
    print('Area under the ROC curve is ', roc_auc_score(test_score, y_pred_proba))
    conf_matx = confusion_matrix(test_score,pred)
    print('\nConfusion Matrix :\n', conf_matx)
    norm_conf_matx = conf_matx / conf_matx.astype(np.float).sum(axis=1).reshape(2,1)
    print('\nNormalized Confusion Matrix :\n', norm_conf_matx)
    plt.figure(figsize=(8,5))
    plot = sns.heatmap(conf_matx, annot=True, fmt = 'g', cmap = 'RdPu',\
                       xticklabels=['Negative Review', 'Positive Review'], yticklabels=['Negative Review','Positive Review'])
    plot.set_yticklabels(plot.get_yticklabels(), rotation = 0, fontsize = 10)
    plt.title('Confusion Matrix Heatmap', fontsize=18)
    
    precision, recall, fscore, support = prf1(test_score, pred)
    print('\nPrecision  : {0:.2f}%, {1:.2f}%'.format(precision[0]*100, precision[1]*100))
    print('Recall     : {0:.2f}%, {1:.2f}%'.format(recall[0]*100, recall[1]*100))
    print('F1-score   : {}'.format(fscore))

# %% [markdown]
# ## 6. Bag of Words (BoW)

# %%
train_x, test_x, train_y, test_y = data_split(sorted_data, score)

# %%
#Applying Bag of Word to cleaned text 
#In sklearn BoW is known as CountVectorizer
count_vect = CountVectorizer(min_df = 0, max_features = 500)

# %% [markdown]
# ### [A] Brute Force

# %%
train_err_bow, cv_err_bow = cross_val(train_x, train_y, count_vect, 'BoW', 'brute')

# %%
cv_err_bow = np.reshape(cv_err_bow,(3, 17))
train_err_bow = np.reshape(train_err_bow,(3, 17))

# %%
error_comparision(cv_err_bow, train_err_bow)

# %% [markdown]
# #### Observation:
# * From above cv-error and train-error comparison I'm considering K = 20 as best fit hyper-parameter.

# %%
# vectorizer on train and test data
bow_model = count_vect.fit(train_x['CleanedText'].values)
final_counts_train = standardizer(bow_model.transform(train_x['CleanedText'].values))
final_counts_test = standardizer(bow_model.transform(test_x['CleanedText'].values))

# %%
#Plotting ROC curve for 45-NN model
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 20, 'BoW', algo = 'brute')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for K = '20' is '77.71428571428571'
# Area under the ROC curve is  0.8780168473938607
#
# Confusion Matrix :
#  [[6632 3548]
#  [1132 9688]]
#
# Normalized Confusion Matrix :
#  [[0.65147348 0.34852652]
#  [0.10462107 0.89537893]]
#
# Precision  : 85.42%, 73.19%
# Recall     : 65.15%, 89.54%
# F1-score   : [0.73918859 0.80545394]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for K = '20' is '70.41111111111111'
# Area under the ROC curve is  0.819343321288888
#
# Confusion Matrix :
#  [[2675 2145]
#  [ 518 3662]]
#
# Normalized Confusion Matrix :
#  [[0.55497925 0.44502075]
#  [0.12392344 0.87607656]]
#
# Precision  : 83.78%, 63.06%
# Recall     : 55.50%, 87.61%
# F1-score   : [0.66766504 0.73335336]

# %% [markdown]
# #### Observation:
# * For K = 20 we are getting total accuracy of 77.71%. for train data and 70.41% for test data.
# * Except that F1 scores are also pretty reasonable.

# %% [markdown]
# ### [B] KD-Tree

# %%
train_err_bow, cv_err_bow = cross_val(train_x, train_y, count_vect, 'BoW', 'kd_tree')

# %%
cv_err_bow = np.reshape(cv_err_bow,(3, 17))
train_err_bow = np.reshape(train_err_bow,(3, 17))

# %%
error_comparision(cv_err_bow, train_err_bow)

# %% [markdown]
# #### Observation:
# * We got similar result to the brute force method.

# %%
final_counts_train = final_counts_train.toarray()
final_counts_test = final_counts_test.toarray()

# %%
final_test_acc(final_counts_train, train_y, final_counts_test, test_y, 20, 'BoW', algo = 'kd_tree')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for K = '20' is '77.57619047619048'
# Area under the ROC curve is  0.8776643385784166
#
# Confusion Matrix :
#  [[6589 3591]
#  [1118 9702]]
#
# Normalized Confusion Matrix :
#  [[0.64724951 0.35275049]
#  [0.10332717 0.89667283]]
#
# Precision  : 85.49%, 72.99%
# Recall     : 64.72%, 89.67%
# F1-score   : [0.73673618 0.80471115]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for K = '20' is '70.17777777777778'
# Area under the ROC curve is  0.8192113949055968
#
# Confusion Matrix :
#  [[2652 2168]
#  [ 516 3664]]
#
# Normalized Confusion Matrix :
#  [[0.55020747 0.44979253]
#  [0.12344498 0.87655502]]
#
# Precision  : 83.71%, 62.83%
# Recall     : 55.02%, 87.66%
# F1-score   : [0.66399599 0.73192169]

# %% [markdown]
# #### Observation:
# * We got similar result as the previous one.

# %% [markdown]
# ## 7. TF-IDF

# %%
#Finding TF-IDF vector representation 
tf_idf_vect = TfidfVectorizer(max_features = 500)

# %% [markdown]
# ### [A] Brute Force

# %%
train_err_tf_idf, cv_err_tf_idf = cross_val(train_x, train_y, tf_idf_vect, 'TFIDF', 'brute')

# %%
cv_err_tfidf = np.reshape(cv_err_tf_idf,(3, 17))
train_err_tfidf = np.reshape(train_err_tf_idf,(3, 17))

# %%
error_comparision(cv_err_tfidf, train_err_tfidf)

# %% [markdown]
# #### Observation:
# * From above cv-error and train-error comparison it seems best fit K is 40.

# %%
# vectorizer on train and test data
tfidf_model = tf_idf_vect.fit(train_x['CleanedText'].values)
tfidf_counts_train = standardizer(tfidf_model.transform(train_x['CleanedText'].values))
tfidf_counts_test = standardizer(tfidf_model.transform(test_x['CleanedText'].values))

# %%
final_test_acc(tfidf_counts_train, train_y, tfidf_counts_test, test_y, 40, 'TFIDF', algo = 'brute')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for K = '40' is '69.85714285714286'
# Area under the ROC curve is  0.8611207234656043
#
# Confusion Matrix :
#  [[ 4400  5780]
#  [  550 10270]]
#
# Normalized Confusion Matrix :
#  [[0.43222004 0.56777996]
#  [0.05083179 0.94916821]]
#
# Precision  : 88.89%, 63.99%
# Recall     : 43.22%, 94.92%
# F1-score   : [0.58162591 0.76442129]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for K = '40' is '63.67777777777778'
# Area under the ROC curve is  0.826734350493359
#
# Confusion Matrix :
#  [[1737 3083]
#  [ 186 3994]]
#
# Normalized Confusion Matrix :
#  [[0.36037344 0.63962656]
#  [0.04449761 0.95550239]]
#
# Precision  : 90.33%, 56.44%
# Recall     : 36.04%, 95.55%
# F1-score   : [0.51520095 0.70960291]

# %% [markdown]
# #### Observation:
# * For K = 40 we are getting total accuracy of 69.85%. for train data and 63.67% for test data.
# * Except that F1 scores is not that good for negative class.

# %% [markdown]
# ### [B] KD-Tree

# %%
train_err_tf_idf, cv_err_tf_idf = cross_val(train_x, train_y, tf_idf_vect, 'TFIDF', 'kd_tree')

# %%
cv_err_tfidf = np.reshape(cv_err_tf_idf,(3, 17))
train_err_tfidf = np.reshape(train_err_tf_idf,(3, 17))

# %%
error_comparision(cv_err_tfidf, train_err_tfidf)

# %% [markdown]
# #### Observation:
# * From above cv-error and train-error comparison it seems best fit K is 40.

# %%
tfidf_counts_train = tfidf_counts_train.toarray()
tfidf_counts_test = tfidf_counts_test.toarray()

# %%
final_test_acc(tfidf_counts_train, train_y, tfidf_counts_test, test_y, 40, 'TFIDF', algo = 'kd_tree')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for K = '40' is '69.84761904761905'
# Area under the ROC curve is  0.8611349589096811
#
# Confusion Matrix :
#  [[ 4398  5782]
#  [  550 10270]]
#
# Normalized Confusion Matrix :
#  [[0.43202358 0.56797642]
#  [0.05083179 0.94916821]]
#
# Precision  : 88.88%, 63.98%
# Recall     : 43.20%, 94.92%
# F1-score   : [0.58143839 0.76436439]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for K = '40' is '63.67777777777778'
# Area under the ROC curve is  0.8267331096507773
#
# Confusion Matrix :
#  [[1738 3082]
#  [ 187 3993]]
#
# Normalized Confusion Matrix :
#  [[0.36058091 0.63941909]
#  [0.04473684 0.95526316]]
#
# Precision  : 90.29%, 56.44%
# Recall     : 36.06%, 95.53%
# F1-score   : [0.5153447  0.70955131]

# %% [markdown]
# #### Observation:
# * We got similar result as the previous one.

# %% [markdown]
# ## 8. Word2Vec

# %%
#Importing Libraries 
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

# %%
#Cleaning html tags
def cleanhtml(sentence): 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', sentence)
    return cleantext

#Cleaning special symbols from texts
def cleanpunc(sentence): 
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned

# %%
#cleaning each text
import re
i = 0
list_of_sent = []
for sent in sorted_data['Text'].values:
    filtered_sentence = []
    sent = cleanhtml(sent)
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if(cleaned_words.isalpha()):    
                filtered_sentence.append(cleaned_words.lower())
            else:
                continue 
    list_of_sent.append(filtered_sentence)

# %%
print(sorted_data['Text'].values[0])
print(list_of_sent[0])
# Out:
# this witty little book makes my son laugh at loud. i recite it in the car as we're driving along and he always can sing the refrain. he's learned about whales, India, drooping roses:  i love all the new words this book  introduces and the silliness of it all.  this is a classic book i am  willing to bet my son will STILL be able to recite from memory when he is  in college
# ['this', 'witty', 'little', 'book', 'makes', 'my', 'son', 'laugh', 'at', 'loud', 'i', 'recite', 'it', 'in', 'the', 'car', 'as', 'were', 'driving', 'along', 'and', 'he', 'always', 'can', 'sing', 'the', 'refrain', 'hes', 'learned', 'about', 'whales', 'india', 'drooping', 'i', 'love', 'all', 'the', 'new', 'words', 'this', 'book', 'introduces', 'and', 'the', 'silliness', 'of', 'it', 'all', 'this', 'is', 'a', 'classic', 'book', 'i', 'am', 'willing', 'to', 'bet', 'my', 'son', 'will', 'still', 'be', 'able', 'to', 'recite', 'from', 'memory', 'when', 'he', 'is', 'in', 'college']

# %%
import gensim
w2v_model = gensim.models.Word2Vec(list_of_sent,min_count=5,size=100, workers=4)

# %%
words = list(w2v_model.wv.vocab)
print(len(words))
# Out:
# 20878

# %% [markdown]
# ## 9. Avg Word2Vec & TF-IDF Word2Vec

# %%
#Determining average Word2Vec for each review
def avg_w2v(data, model):
    sent_vectors = []
    for sent in data: 
        sent_vec = np.zeros(100) 
        cnt_words =0; 
        for word in sent: # for each word in a review/sentence
            try:
                vec = model.wv[word]
                sent_vec += vec
                cnt_words += 1
            except:
                pass
        sent_vec /= cnt_words
        sent_vectors.append(sent_vec)
    return np.matrix(sent_vectors)

# %%
train_list_x, test_list_x, train_y, test_y = data_split(list_of_sent, score)

# %% [markdown]
# ### [A] Brute Force

# %%
train_err_w2v, cv_err_w2v = cross_val(np.array(train_list_x), np.array(train_y), None, 'Word2Vec', 'brute')

# %%
cv_err_w2v = np.reshape(cv_err_w2v,(3, 17))
train_err_w2v = np.reshape(train_err_w2v,(3, 17))

# %%
error_comparision(cv_err_w2v, train_err_w2v)

# %% [markdown]
# #### Observation:
# * Now the model performs reasonably well for word2vec representation. And I'm taking 32 as best-fit K for my model.

# %%
# applying w2v to train and test data
w2v_model = gensim.models.Word2Vec(train_list_x, min_count=5, size=100, workers=8)
train_vect = avg_w2v(train_list_x, w2v_model)
test_vect = avg_w2v(test_list_x, w2v_model)

# %%
train_vect = np.nan_to_num(train_vect)
test_vect = np.nan_to_num(test_vect)

# %%
final_test_acc(train_vect, train_y, test_vect, test_y, 32, 'Word2Vec', 'brute')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for K = '32' is '78.92857142857143'
# Area under the ROC curve is  0.8785907591268444
#
# Confusion Matrix :
#  [[8389 1791]
#  [2634 8186]]
#
# Normalized Confusion Matrix :
#  [[0.8240668  0.1759332 ]
#  [0.24343808 0.75656192]]
#
# Precision  : 76.10%, 82.05%
# Recall     : 82.41%, 75.66%
# F1-score   : [0.79130312 0.78722893]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for K = '32' is '77.16666666666666'
# Area under the ROC curve is  0.8495572177331295
#
# Confusion Matrix :
#  [[3943  877]
#  [1178 3002]]
#
# Normalized Confusion Matrix :
#  [[0.81804979 0.18195021]
#  [0.28181818 0.71818182]]
#
# Precision  : 77.00%, 77.39%
# Recall     : 81.80%, 71.82%
# F1-score   : [0.79328035 0.74500558]

# %% [markdown]
# #### Observation:
# * For K = 32 we are getting total accuracy of 78.92% for training set and 77.16% for test set.
# * True Positive and True negative rates are good, which is 79% and 74%.
# * K-NN Performs better for average word2vec than that of BoW and TF-IDF.

# %% [markdown]
# ### 9.1 TF-IDF weighted Word2Vec

# %%
# Determining TF-IDF weighted Word2Vec
def tfidf_w2v(data, model, dictionary):
    tfidf_feat = tf_idf_vect.get_feature_names() 
    tfidf_sent_vectors = []
    row = 0
    for sent in data: 
        sent_vec = np.zeros(100)
        weight_sum = 0 
        for word in sent: 
            try:
                vec = model.wv[word]
                tf_idf = dictionary[word] * (sent.count(word)/len(sent))
                sent_vec += (vec * tf_idf)
                weight_sum += tf_idf
            except:
                pass
        sent_vec /= weight_sum
        tfidf_sent_vectors.append(sent_vec)
        row += 1
    return np.matrix(tfidf_sent_vectors)

# %%
trainx, testx, train_y, test_y, train_x_in_list, test_x_in_list = train_test_split(list_of_sent, score, sorted_data.CleanedText.values,
                                                                 test_size=0.3, shuffle=False)

# %% [markdown]
# ### [A] Brute Force

# %%
train_err_tfw2v, cv_err_tfw2v = cross_val(trainx, train_y, train_x_in_list, 'TFIDF-W2V', 'brute')

# %%
cv_err_w2v_tfidf = np.reshape(cv_err_tfw2v,(3, 17))
train_err_w2v_tfidf = np.reshape(train_err_tfw2v,(3, 17))

# %%
error_comparision(cv_err_w2v_tfidf, train_err_w2v_tfidf)

# %% [markdown]
# #### Observation:
# * The error curve seems reasonably fine. And I'm taking 19 as the best fit K for my model.

# %%
w2v_model = gensim.models.Word2Vec(train_x, min_count=5, size=100, workers=-1)
tfidf_model = tf_idf_vect.fit_transform(train_x_in_list)
tfidf_dict = dict(zip(tf_idf_vect.get_feature_names(), list(tf_idf_vect.idf_)))
train_vect = tfidf_w2v(train_x_in_list, w2v_model, tfidf_dict)
test_vect = tfidf_w2v(test_x_in_list, w2v_model, tfidf_dict)

# %%
train_vect = np.nan_to_num(train_vect)
test_vect = np.nan_to_num(test_vect)

# %%
final_test_acc(train_vect, train_y, test_vect, test_y, 19, 'TFIDF-W2V', 'brute')
# Out:
# 				ACCURACY METRIC FOR TRAIN-SET
#
#
# Train accuracy for K = '19' is '48.47619047619048'
# Area under the ROC curve is  0.5
#
# Confusion Matrix :
#  [[10180     0]
#  [10820     0]]
#
# Normalized Confusion Matrix :
#  [[1. 0.]
#  [1. 0.]]
#
# Precision  : 48.48%, 0.00%
# Recall     : 100.00%, 0.00%
# F1-score   : [0.65298268 0.        ]
# 				ACCURACY METRIC FOR TEST-SET
#
#
# Test accuracy for K = '19' is '53.55555555555556'
# Area under the ROC curve is  0.5
#
# Confusion Matrix :
#  [[4820    0]
#  [4180    0]]
#
# Normalized Confusion Matrix :
#  [[1. 0.]
#  [1. 0.]]
#
# Precision  : 53.56%, 0.00%
# Recall     : 100.00%, 0.00%
# F1-score   : [0.6975398 0.       ]

# %% [markdown]
# #### Observation:
# * From the confusion matrix it is clear that the model does not learn anything. It just assigns all the data points to the negative class.

# %% [markdown]
# ## 10. Summary:

# %% [markdown]
# ### Approach:
# <p align="center">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;From all Amazon fine food reviews data-points i have taken only the reviews that have score 1, 2, 4 or 5. Then I applied some pre-processing methods to make data best fit to apply KNN model. After that I have declared some useful functions to modularize the whole process. For our end goal i.e to classify a review whether it is positive or not by using naive bayes, we need to convert the textual data to numerial one. To do so i have used these two(given below) vectorization methods.<br>
# </p>
# <br>
# 1. Bag of Words(BoW)<br>
# 2. TF-IDF<br>
# 3. Avg Word2Vec<br>
# 4. TFIDF-W2V<br>
# <p align="center">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Before applying any model to our data we need to split the data into train and test set. Here I have taken 70% of the total data as train-set and rest 30% as test-data. The important part here is "I have sorted the data in ascending order of time stamp of the reviews" and then splitted the whole data without shuffling it. The only problem with KNN is that it is hugely impacted by imbalanced data. That is why i took 15000 positive points and 15000 negative points before sorting them according to time.
# </p>
#
# <h3> Results:</h3>
# <p align="center">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In KNN we have got K which is a hyper-parameter which handles the trade-off between overfitting and underfitting. To find best fit K, I have used 3-Fold cross validation for each vectorization method and the performance of the model is compared by various accuracy matrics(ROC-AUC curve, precision, recall, F1-Score etc.) for each vectorization.
# </p>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>1. BoW</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For BoW representation, we got best-fit K = 20 from 3-Fold cross validation. And the accuracy metric for train and test data, taking K = 20, is given below:-
#  <table>
#   <tr>
#     <th>Data</th>
#     <th>K</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>20</td>
#     <td>77.71%</td>
#     <td>85.42%, 73.19%</td>
#     <td>65.15%, 89.54%</td>
#     <td>0.74 0.80</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>20</td>
#     <td>70.41%</td>
#     <td>83.78%, 63.06%</td>
#     <td>55.50%, 87.61%</td>
#     <td>0.66 0.73</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 77.71% accuracy for train-data and 70.41% for test-data. But from F1-Score it is clear that our model is not that good in predicting negative class compared to the positive prediction.
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>3. TF-IDF</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For TF-IDF representation, we got best-fit K = 40 from 3-Fold cross validation. And the accuracy metric for train and test data, taking K = 40, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>K</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>40</td>
#     <td>69.85%</td>
#     <td>88.89%, 63.99%</td>
#     <td>43.22%, 94.92%</td>
#     <td>0.58 0.76</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>40</td>
#     <td>63.67%</td>
#     <td>90.29%, 56.44%</td>
#     <td>36.06%, 95.53%</td>
#     <td>0.51  0.71</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 69.85% accuracy with high F1-Scores for train-data and 63.67% for test-data. But for test-data, negative class F1-Score is 0.51 which is too low compared to positive class F1-Score 0.71. So the TF-IDF representation didn't help the model much to classify properly for this given data.
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>3. Avg Word2Vec</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For Avg Word2Vec representation, we got best-fit K = 32 from 3-Fold cross validation. And the accuracy metric for train and test data, taking K = 32, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>K</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>32</td>
#     <td>78.92%</td>
#     <td>76.10%, 82.05%</td>
#     <td>82.41%, 75.66%</td>
#     <td>0.79 0.78</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>32</td>
#     <td>77.16%</td>
#     <td>77.00%, 77.39%</td>
#     <td>81.80%, 71.82%</td>
#     <td>0.79 0.74</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got 78.92% accuracy with good F1-Scores for train-data and 77.16% for test-data. For test-data, negative class F1-Score is also pretty good i.e 0.79 and 0.74.
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h4>4. TF-IDF W2V</h4><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For TF-IDF W2V representation, we got best-fit K = 19 from 3-Fold cross validation. And the accuracy metric for train and test data, taking K = 19, is given below:-
# <table>
#   <tr>
#     <th>Data</th>
#     <th>K</th>
#     <th>Accuracy</th>
#     <th>Precision</th>
#     <th>Recall</th>
#     <th>F1-Score</th>
#   </tr>
#   <tr>
#     <td>Train</td>
#     <td>19</td>
#     <td>48.47%</td>
#     <td>48.48%, 0.00%</td>
#     <td>100.00%, 0.00%</td>
#     <td>0.65298268 0.</td>
#   </tr>
#   <tr>
#     <td>Test</td>
#     <td>19</td>
#     <td>53.55%</td>
#     <td>53.56%, 0.00%</td>
#     <td>100.00%, 0.00%</td>
#     <td>0.69 0.</td>
#   </tr>
# </table>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The model got only 53.55% accuracy with worst F1-Score. For TFIDF-W2V the model actually does not learn anything; it just assigns all the data point to the negative class.<br>
# <h3> Conclusion:</h3><br>
# 1. K-NN algorithm's performance for text classification is better than average but not that good.<br>
# 2. In our case K-NN performs better(i.e ~ 77%) for Avg-Word2Vec representation of text data.<br>
# 3. Among Bag of Words and TFIDF representation the model performed better for Bag of Words.<br>
